# %% [markdown]
# <a href="https://colab.research.google.com/github/LordLean/Extracting-Green-Bonds-Use-of-Proceeds/blob/main/evaluation/retriever_evaluation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Information Retieval

# %% [markdown]
# ## Answer Retriever

# %%
# !pip install rank-bm25

# !pip install PyPDF2

# !pip install tabula-py
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting rank-bm25
#   Downloading rank_bm25-0.2.2-py3-none-any.whl (8.6 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from rank-bm25) (1.21.6)
# Installing collected packages: rank-bm25
# Successfully installed rank-bm25-0.2.2
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting PyPDF2
#   Downloading PyPDF2-2.10.3-py3-none-any.whl (214 kB)
#      |████████████████████████████████| 214 kB 3.9 MB/s
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from PyPDF2) (4.1.1)
# Installing collected packages: PyPDF2
# Successfully installed PyPDF2-2.10.3
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tabula-py
#   Downloading tabula_py-2.5.1-py3-none-any.whl (12.0 MB)
#      |████████████████████████████████| 12.0 MB 5.3 MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from tabula-py) (1.21.6)
# Collecting distro
#   Downloading distro-1.7.0-py3-none-any.whl (20 kB)
# Requirement already satisfied: pandas>=0.25.3 in /usr/local/lib/python3.7/dist-packages (from tabula-py) (1.3.5)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.25.3->tabula-py) (2022.2.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.25.3->tabula-py) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.25.3->tabula-py) (1.15.0)
# Installing collected packages: distro, tabula-py
# Successfully installed distro-1.7.0 tabula-py-2.5.1

# %%
import numpy as np

import tabula
from rank_bm25 import BM25Okapi
from PyPDF2 import PdfReader

# %%
class TableReader:

  def __init__(self, pdf):
    self.pdf = pdf
    self.dfs = None

  def read_pages(self, pages="all", multiple_tables=True, stream=True):
    '''
    Return tables discovered within pdf.
    '''
    self.dfs = tabula.read_pdf(self.pdf, pages=pages, multiple_tables=multiple_tables, stream=stream)
    self.__clean_dfs()
    return self.dfs

  def __clean_dfs(self, thresh=2):
    self.dfs = [df.dropna(thresh=thresh) for df in self.dfs]


class Reader:

  def __init__(self, filename):
    self.reader = PdfReader(filename)
    self.tb = TableReader(filename)
    self.page_viewer = {page_num : {} for page_num in range(self.reader.numPages)}
    self.idx2page_item = []
  
  def __extract_text(self,):
    '''
    Page-wise text extraction and tokenize for BM25.
    '''
    text_index_mem = 0
    # List to store each tokenized corpus
    tokenized_corpus_list = []
    for i in range(self.reader.numPages):
      raw_text = self.reader.getPage(i).extractText()
      self.page_viewer[i]["raw_text"] = raw_text
      # Split text
      corpus = raw_text.split("\n \n")
      # Store results.
      self.page_viewer[i]["corpus"] = corpus
      for item in corpus:
        self.idx2page_item.append((i, item)) # page,textItem
      # Tokenize
      tokenized_corpus = [doc.split(" ") for doc in corpus]
      tokenized_corpus_list.append(tokenized_corpus)
    # BM25 computations only after the complete tokenized corpus is collated. 
    # Merge tokenized corpus'.
    tokenized_corpus_complete = [item for sublist in tokenized_corpus_list for item in sublist]
    # BM25
    self.bm25 = BM25Okapi(tokenized_corpus_complete)

  def __extract_tables(self):
    '''
    Page-wise table extractor.
    '''
    for i in range(self.reader.numPages):
      # page=0 will throw error using tabula.
      page = str(i+1)
      self.page_viewer[i]["tables"] = self.tb.read_pages(pages=page)

  def extract_pdf(self):
    # Extract data
    self.__extract_text()
    # self.__extract_tables()

  def print_page(self, page_num):
    '''
    Print separated sections of text given a page.
    '''
    corpus = self.page_viewer[page_num]["corpus"]
    for item in (corpus):
      print("\n{}\n".format("-"*60))
      print(item)
    print("\n{}\n".format("-"*60))
    for df in self.page_viewer[page_num]["tables"]:
      print(df.style)
      display(df)

  def __score(self, queries, weights):
    '''
    Compute the average BM25 score of each given query on each page of text.
    '''
    self.ranked_scores = []
    for query in queries:
      # tokenize query by whitespace.
      tokenized_query = query.split()
      # Compute score.
      doc_scores = self.bm25.get_scores(tokenized_query)
      self.ranked_scores.append(doc_scores)
    # Compute average (weighted) score against all queries.
    if not len(weights):
      # Equal weighting.
      self.average_score = np.average(self.ranked_scores, axis=0)
    elif len(queries) != len(weights):
        # Unequal number of elements.
        raise ValueError("Number of query and weight elements passed must be equal.")
    else:
      # Weighted average.
      self.average_score = np.average(self.ranked_scores, weights=weights, axis=0)
 
  def get_ranked_texts(self, queries, weights=[], n=5):
    '''
    Return n pages which scored highest using BM25.
    '''
    # Run score method to calculate BM25.
    self.__score(queries, weights)
    try:
      idx = sorted(range(len(self.average_score)), key=lambda i: self.average_score[i], reverse=True)[:n]
    except IndexError:
      idx = sorted(range(len(self.average_score)), key=lambda i: self.average_score[i], reverse=True)
    final_results = []
    for i in range(n):
      page_num, text = self.idx2page_item[idx[i]]
      # tables = self.page_viewer[page_num]["tables"]
      # final_results.append({"page_num":page_num, "text":text, "tables":tables})
      final_results.append(text)

    return final_results

# %% [markdown]
# ## Answer Re-ranker (Neural: BERT / T5)

# %%
# !pip install pygaggle

# !pip install transformers==4.6.1
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pygaggle
#   Downloading pygaggle-0.0.3.1.tar.gz (33 kB)
# Collecting coloredlogs==14.0
#   Downloading coloredlogs-14.0-py2.py3-none-any.whl (43 kB)
#      |████████████████████████████████| 43 kB 2.3 MB/s
# Requirement already satisfied: numpy>=1.18 in /usr/local/lib/python3.7/dist-packages (from pygaggle) (1.21.6)
# Collecting pydantic==1.5
#   Downloading pydantic-1.5-cp37-cp37m-manylinux2014_x86_64.whl (7.3 MB)
#      |████████████████████████████████| 7.3 MB 10.3 MB/s
# Collecting pyserini==0.10.1.0
#   Downloading pyserini-0.10.1.0-py3-none-any.whl (63.3 MB)
#      |████████████████████████████████| 63.3 MB 12 kB/s
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.7/dist-packages (from pygaggle) (1.0.2)
# Requirement already satisfied: scipy>=1.4 in /usr/local/lib/python3.7/dist-packages (from pygaggle) (1.7.3)
# Collecting spacy==2.2.4
#   Downloading spacy-2.2.4-cp37-cp37m-manylinux1_x86_64.whl (10.6 MB)
#      |████████████████████████████████| 10.6 MB 6.2 MB/s
# Requirement already satisfied: tensorboard>=2.1.0 in /usr/local/lib/python3.7/dist-packages (from pygaggle) (2.8.0)
# Requirement already satisfied: tensorflow>=2.2.0rc1 in /usr/local/lib/python3.7/dist-packages (from pygaggle) (2.8.2+zzzcolab20220719082949)
# Collecting tokenizers==0.9.4
#   Downloading tokenizers-0.9.4-cp37-cp37m-manylinux2010_x86_64.whl (2.9 MB)
#      |████████████████████████████████| 2.9 MB 41.3 MB/s
# Collecting tqdm==4.45.0
#   Downloading tqdm-4.45.0-py2.py3-none-any.whl (60 kB)
#      |████████████████████████████████| 60 kB 5.1 MB/s
# Collecting transformers==4.0.0
#   Downloading transformers-4.0.0-py3-none-any.whl (1.4 MB)
#      |████████████████████████████████| 1.4 MB 68.6 MB/s
# Collecting sentencepiece==0.1.94
#   Downloading sentencepiece-0.1.94-cp37-cp37m-manylinux2014_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 45.2 MB/s
# Collecting humanfriendly>=7.1
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      |████████████████████████████████| 86 kB 2.8 MB/s
# Requirement already satisfied: Cython in /usr/local/lib/python3.7/dist-packages (from pyserini==0.10.1.0->pygaggle) (0.29.32)
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.7.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.6 MB)
#      |████████████████████████████████| 8.6 MB 43.8 MB/s
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from pyserini==0.10.1.0->pygaggle) (1.3.5)
# Collecting pyjnius
#   Downloading pyjnius-1.4.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 45.9 MB/s
# Collecting srsly<1.1.0,>=1.0.2
#   Downloading srsly-1.0.5-cp37-cp37m-manylinux2014_x86_64.whl (184 kB)
#      |████████████████████████████████| 184 kB 48.9 MB/s
# Collecting catalogue<1.1.0,>=0.0.7
#   Downloading catalogue-1.0.0-py2.py3-none-any.whl (7.7 kB)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy==2.2.4->pygaggle) (3.0.7)
# Collecting thinc==7.4.0
#   Downloading thinc-7.4.0-cp37-cp37m-manylinux1_x86_64.whl (2.2 MB)
#      |████████████████████████████████| 2.2 MB 13.7 MB/s
# Collecting blis<0.5.0,>=0.4.0
#   Downloading blis-0.4.1-cp37-cp37m-manylinux1_x86_64.whl (3.7 MB)
#      |████████████████████████████████| 3.7 MB 46.8 MB/s
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy==2.2.4->pygaggle) (0.10.1)
# Collecting plac<1.2.0,>=0.9.6
#   Downloading plac-1.1.3-py2.py3-none-any.whl (20 kB)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy==2.2.4->pygaggle) (2.0.6)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy==2.2.4->pygaggle) (1.0.8)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy==2.2.4->pygaggle) (57.4.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy==2.2.4->pygaggle) (2.23.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers==4.0.0->pygaggle) (2022.6.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers==4.0.0->pygaggle) (3.8.0)
# Collecting sacremoses
#   Downloading sacremoses-0.0.53.tar.gz (880 kB)
#      |████████████████████████████████| 880 kB 47.7 MB/s
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from transformers==4.0.0->pygaggle) (21.3)
# Requirement already satisfied: importlib-metadata>=0.20 in /usr/local/lib/python3.7/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy==2.2.4->pygaggle) (4.12.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy==2.2.4->pygaggle) (3.8.1)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy==2.2.4->pygaggle) (4.1.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy==2.2.4->pygaggle) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy==2.2.4->pygaggle) (2022.6.15)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy==2.2.4->pygaggle) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy==2.2.4->pygaggle) (2.10)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.22->pygaggle) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.22->pygaggle) (3.1.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.1.0->pygaggle) (1.2.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.1.0->pygaggle) (0.4.6)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.1.0->pygaggle) (1.47.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.1.0->pygaggle) (3.4.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.1.0->pygaggle) (1.0.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.1.0->pygaggle) (1.8.1)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.1.0->pygaggle) (0.37.1)
# Requirement already satisfied: protobuf>=3.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.1.0->pygaggle) (3.17.3)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.1.0->pygaggle) (1.35.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.1.0->pygaggle) (0.6.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.1.0->pygaggle) (0.2.8)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.1.0->pygaggle) (1.15.0)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.1.0->pygaggle) (4.2.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.1.0->pygaggle) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.1.0->pygaggle) (1.3.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.1.0->pygaggle) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.1.0->pygaggle) (3.2.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.2.0rc1->pygaggle) (0.26.0)
# Requirement already satisfied: flatbuffers>=1.12 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.2.0rc1->pygaggle) (2.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.2.0rc1->pygaggle) (0.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.2.0rc1->pygaggle) (3.3.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.2.0rc1->pygaggle) (1.6.3)
# Requirement already satisfied: tensorflow-estimator<2.9,>=2.8 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.2.0rc1->pygaggle) (2.8.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.2.0rc1->pygaggle) (1.1.2)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.2.0rc1->pygaggle) (1.1.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.2.0rc1->pygaggle) (1.14.1)
# Requirement already satisfied: libclang>=9.0.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.2.0rc1->pygaggle) (14.0.6)
# Requirement already satisfied: keras<2.9,>=2.8.0rc0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.2.0rc1->pygaggle) (2.8.0)
# Requirement already satisfied: gast>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.2.0rc1->pygaggle) (0.5.3)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.2.0rc1->pygaggle) (3.1.0)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py>=2.9.0->tensorflow>=2.2.0rc1->pygaggle) (1.5.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->transformers==4.0.0->pygaggle) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->pyserini==0.10.1.0->pygaggle) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->pyserini==0.10.1.0->pygaggle) (2022.2.1)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==4.0.0->pygaggle) (7.1.2)
# Building wheels for collected packages: pygaggle, sacremoses
#   Building wheel for pygaggle (setup.py) ... done
#   Created wheel for pygaggle: filename=pygaggle-0.0.3.1-py3-none-any.whl size=51498 sha256=9c320e6d2d99b26b042a48fda34745055abab2637e051ca8bea883d8355f2948
#   Stored in directory: /root/.cache/pip/wheels/d0/b7/35/6b19949b191b7b5005739e020b91b3a625c3a588a0bd49d70c
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.53-py3-none-any.whl size=895260 sha256=0036f378aaaa5adf7d8f40605f232685606b8ab84560c163bb2b2e1156a4afd3
#   Stored in directory: /root/.cache/pip/wheels/87/39/dd/a83eeef36d0bf98e7a4d1933a4ad2d660295a40613079bafc9
# Successfully built pygaggle sacremoses
# Installing collected packages: tqdm, srsly, plac, catalogue, blis, tokenizers, thinc, sacremoses, pyjnius, humanfriendly, faiss-cpu, transformers, spacy, sentencepiece, pyserini, pydantic, coloredlogs, pygaggle
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.64.0
#     Uninstalling tqdm-4.64.0:
#       Successfully uninstalled tqdm-4.64.0
#   Attempting uninstall: srsly
#     Found existing installation: srsly 2.4.4
#     Uninstalling srsly-2.4.4:
#       Successfully uninstalled srsly-2.4.4
#   Attempting uninstall: catalogue
#     Found existing installation: catalogue 2.0.8
#     Uninstalling catalogue-2.0.8:
#       Successfully uninstalled catalogue-2.0.8
#   Attempting uninstall: blis
#     Found existing installation: blis 0.7.8
#     Uninstalling blis-0.7.8:
#       Successfully uninstalled blis-0.7.8
#   Attempting uninstall: thinc
#     Found existing installation: thinc 8.1.0
#     Uninstalling thinc-8.1.0:
#       Successfully uninstalled thinc-8.1.0
#   Attempting uninstall: spacy
#     Found existing installation: spacy 3.4.1
#     Uninstalling spacy-3.4.1:
#       Successfully uninstalled spacy-3.4.1
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 1.9.2
#     Uninstalling pydantic-1.9.2:
#       Successfully uninstalled pydantic-1.9.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# panel 0.12.1 requires tqdm>=4.48.0, but you have tqdm 4.45.0 which is incompatible.
# en-core-web-sm 3.4.0 requires spacy<3.5.0,>=3.4.0, but you have spacy 2.2.4 which is incompatible.
# Successfully installed blis-0.4.1 catalogue-1.0.0 coloredlogs-14.0 faiss-cpu-1.7.2 humanfriendly-10.0 plac-1.1.3 pydantic-1.5 pygaggle-0.0.3.1 pyjnius-1.4.2 pyserini-0.10.1.0 sacremoses-0.0.53 sentencepiece-0.1.94 spacy-2.2.4 srsly-1.0.5 thinc-7.4.0 tokenizers-0.9.4 tqdm-4.45.0 transformers-4.0.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers==4.6.1
#   Downloading transformers-4.6.1-py3-none-any.whl (2.2 MB)
#      |████████████████████████████████| 2.2 MB 5.8 MB/s
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers==4.6.1) (1.21.6)
# Collecting tokenizers<0.11,>=0.10.1
#   Downloading tokenizers-0.10.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 44.2 MB/s
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers==4.6.1) (4.45.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers==4.6.1) (4.12.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers==4.6.1) (2.23.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers==4.6.1) (2022.6.2)
# Collecting huggingface-hub==0.0.8
#   Downloading huggingface_hub-0.0.8-py3-none-any.whl (34 kB)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.7/dist-packages (from transformers==4.6.1) (0.0.53)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers==4.6.1) (3.8.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from transformers==4.6.1) (21.3)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers==4.6.1) (4.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers==4.6.1) (3.8.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->transformers==4.6.1) (3.0.9)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.6.1) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.6.1) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.6.1) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==4.6.1) (2022.6.15)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==4.6.1) (1.15.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==4.6.1) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==4.6.1) (1.1.0)
# Installing collected packages: tokenizers, huggingface-hub, transformers
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.9.4
#     Uninstalling tokenizers-0.9.4:
#       Successfully uninstalled tokenizers-0.9.4
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.0.0
#     Uninstalling transformers-4.0.0:
#       Successfully uninstalled transformers-4.0.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pygaggle 0.0.3.1 requires tokenizers==0.9.4, but you have tokenizers 0.10.3 which is incompatible.
# pygaggle 0.0.3.1 requires transformers==4.0.0, but you have transformers 4.6.1 which is incompatible.
# Successfully installed huggingface-hub-0.0.8 tokenizers-0.10.3 transformers-4.6.1

# %%
from pygaggle.rerank.base import Query, Text
from pygaggle.rerank.transformer import MonoT5, MonoBERT

class Reranker:

  def __init__(self):
    self.mono5t = MonoT5()
    self.monobert = MonoBERT()

  def rerank(self, query, texts, method="T5"):
    query = Query(query)
    texts = [Text(text, {"docid" : i}, 0) for i, text in enumerate(texts)]

    if method == "T5":
      reranker = self.mono5t
    if method == "BERT":
      reranker = self.monobert

    reranked = reranker.rerank(query, texts)
    reranked.sort(key=lambda x: x.score, reverse=True)

    return reranked
# Out:
# 2022-08-25 12:23:34 [INFO] loader: Loading faiss with AVX2 support.
# 2022-08-25 12:23:34 [INFO] loader: Could not load library with AVX2 support due to:
# ModuleNotFoundError("No module named 'faiss.swigfaiss_avx2'")
# 2022-08-25 12:23:34 [INFO] loader: Loading faiss.
# 2022-08-25 12:23:34 [INFO] loader: Successfully loaded faiss.

# %% [markdown]
# # ICMA Database Upload

# %%
# !wget https://www.icmagroup.org/assets/documents/Sustainable-finance/Database/ICMA-Sustainable-Bonds-Database-120822.xlsx
# Out:
# --2022-08-25 12:23:36--  https://www.icmagroup.org/assets/documents/Sustainable-finance/Database/ICMA-Sustainable-Bonds-Database-120822.xlsx
# Resolving www.icmagroup.org (www.icmagroup.org)... 91.216.93.249
# Connecting to www.icmagroup.org (www.icmagroup.org)|91.216.93.249|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 274575 (268K) [application/vnd.openxmlformats-officedocument.spreadsheetml.sheet]
# Saving to: ‘ICMA-Sustainable-Bonds-Database-120822.xlsx’
#
# ICMA-Sustainable-Bo 100%[===================>] 268.14K   760KB/s    in 0.4s
#
# 2022-08-25 12:23:37 (760 KB/s) - ‘ICMA-Sustainable-Bonds-Database-120822.xlsx’ saved [274575/274575]

# %%
import os
import pandas as pd
import openpyxl

# %%
filename = "ICMA-Sustainable-Bonds-Database-120822.xlsx"

# select green bond sheet.
gb_sheet = pd.ExcelFile(filename).sheet_names[0] 

df = pd.read_excel(filename, sheet_name=gb_sheet, header=1)

# %%
# Use openpyxl to load xls with hyperlink text.
wb = openpyxl.load_workbook(filename)
ws = wb[gb_sheet]

hyperlink_list = []

for i in range(len(df)):
  try:
    hyperlink_list.append(ws.cell(row=(3+i), column=6).hyperlink.target)
  except:
    # Nan 
    hyperlink_list.append(None)

# Add list to df.
df["External Review Report Text"] = hyperlink_list

# %%
df["Issuer Category/Sector"].unique()
# Out:
# array(['Financial Institution', 'Corporate-Energy', 'Utility',
#        'Corporate-Infrastructure', 'Corporate-Real Estate',
#        'Corporate-Transportation', 'MDB', 'Agency', 'Corporate-agri food',
#        'Corporate-Consumer services', 'Corporate-Consumer goods',
#        'Sovereign', 'Corporate-Industry', 'Municipal', nan,
#        'Corporate-Technology', 'Corporate-consumer services',
#        'Corporate-Tourism', 'Corporate-Real estate', 'Corporate-Telecom',
#        'Corporate-Water', 'Corporate-Healthcare'], dtype=object)

# %%
sectors = ["Corporate-Real Estate", "Corporate-Energy", "Corporate-Transportation"]

# %%
european = [
    'Spain', "The Netherlands", "Italy", "Sweden", "Norway", "France", "Luxembourg",
    "UK", "Belgium", "Hungary", "Switzerland", "Germany", "Finland", "Iceland", "Poland",
    "Czech Republic", "Denmark", "Ireland", "Greece", "Guernsey", "Austria", "Latvia",
    "Lithuania", "Romania", "Slovenia", "Slovakia",
]

sector = "Corporate-Real Estate"
# sector = "Corporate-Energy"
# sector = "Corporate-Transportation"
external = "sustainalytics".upper() # second-party opinion


df = df.loc[
    (df["Jurisdiction"].isin(european)) &
    (df["Issuer Category/Sector"] == sector) &
    (df["External Review Report"] == external)
] 

files = df["External Review Report Text"].to_list()

# %%
sector_name2url = {}

# %%
name2url = {link.strip().rsplit('/', 1)[-1] : link.strip() for link in files}
url2name = {link.strip() : link.strip().rsplit('/', 1)[-1]for link in files}
url2name
# Out:
# {'https://www.icmagroup.org/Emails/icma-vcards/Blackstone_External%20Review%20Report.pdf': 'Blackstone_External%20Review%20Report.pdf',
#  'http://www.icmagroup.org/Emails/icma-vcards/Castellum_External%20Review%20Report.pdf': 'Castellum_External%20Review%20Report.pdf',
#  'https://www.icmagroup.org/Emails/icma-vcards/Cibus_External%20Review%20Report.pdf': 'Cibus_External%20Review%20Report.pdf',
#  'https://www.icmagroup.org/Emails/icma-vcards/CTP_External%20Review%20Report.pdf': 'CTP_External%20Review%20Report.pdf',
#  'https://www.icmagroup.org/Emails/icma-vcards/Deutsche%20Wohnen_External%20Review%20Report.pdf': 'Deutsche%20Wohnen_External%20Review%20Report.pdf',
#  'https://www.icmagroup.org/Emails/icma-vcards/Globalworth_External%20Review%20Report.pdf': 'Globalworth_External%20Review%20Report.pdf',
#  'http://www.icmagroup.org/Emails/icma-vcards/ICADE_External%20Review%20Report.pdf': 'ICADE_External%20Review%20Report.pdf',
#  'https://www.icmagroup.org/Emails/icma-vcards/Johnson_External%20Review%20Report.pdf': 'Johnson_External%20Review%20Report.pdf',
#  'https://www.icmagroup.org/Emails/icma-vcards/Specialfastigheter-External%20Review%20Report.pdf': 'Specialfastigheter-External%20Review%20Report.pdf',
#  'https://www.icmagroup.org/Emails/icma-vcards/tritax-eurobox_External%20Review%20Report.pdf': 'tritax-eurobox_External%20Review%20Report.pdf',
#  'https://www.icmagroup.org/Emails/icma-vcards/Vesteda_External%20Review%20Report.pdf': 'Vesteda_External%20Review%20Report.pdf',
#  'https://www.icmagroup.org/Emails/icma-vcards/V%C3%ADa%20C%C3%A9lere_External%20Review%20Report.pdf': 'V%C3%ADa%20C%C3%A9lere_External%20Review%20Report.pdf',
#  'https://www.icmagroup.org/Emails/icma-vcards/Vonovia_External%20Review%20Report.pdf': 'Vonovia_External%20Review%20Report.pdf',
#  'https://www.icmagroup.org/Emails/icma-vcards/Xior_External%20Review%20Report.pdf': 'Xior_External%20Review%20Report.pdf'}

# %%
sector_name2url[sector] = name2url

# %%
for sector in sectors:
  print(sector)
  for company in sector_name2url[sector].keys():
    print("     " +company)
  print("\n\n")
# Out:
# Corporate-Real Estate
#      Blackstone_External%20Review%20Report.pdf
#      Castellum_External%20Review%20Report.pdf
#      Cibus_External%20Review%20Report.pdf
#      CTP_External%20Review%20Report.pdf
#      Deutsche%20Wohnen_External%20Review%20Report.pdf
#      Globalworth_External%20Review%20Report.pdf
#      ICADE_External%20Review%20Report.pdf
#      Johnson_External%20Review%20Report.pdf
#      Specialfastigheter-External%20Review%20Report.pdf
#      tritax-eurobox_External%20Review%20Report.pdf
#      Vesteda_External%20Review%20Report.pdf
#      V%C3%ADa%20C%C3%A9lere_External%20Review%20Report.pdf
#      Vonovia_External%20Review%20Report.pdf
#      Xior_External%20Review%20Report.pdf
#
#
#
# Corporate-Energy
#      Baseload%20Capital_External%20Review%20Report.pdf
#      E.ON_External%20Review%20Report.pdf
#      E.ON_External%20Review%20Report%202021.pdf
#      ESB_External%20Review%20Report.pdf
#      innogy_External%20Review%20Report.pdf
#      Midsummer_External%20Review%20Report.pdf
#      Landsvirkjun-External%20Review%20Report.pdf
#      neutral%20fuels_External%20Review%20Report.pdf
#      Repower_External%20Review%20Report.pdf
#      RWE_External%20Review%20Report.pdf
#      Synthesis%20Analytics_External%20Review%20Report.pdf
#      Water%20Wheel_External%20Review%20Report.pdf
#
#
#
# Corporate-Transportation
#      Alpha%20Trains_External%20Review%20Report.pdf
#      Ferrovie_External%20Review%20Report.pdf
#      Volkswagen_External%20Review%20Report%202020.pdf

# %%
cwd = os.getcwd()

path = os.path.join(cwd, "documents")

os.mkdir(path)

for sec in sectors:
  os.mkdir(os.path.join(path, sec))

# # Create documents folder
# !mkdir documents
# # Create sector Specific directory
# !mkdir documents/Corporate-Energy

# %%
import os.path
import urllib.request

for link, name in url2name.items():
    filename = os.path.join('./documents/{}'.format(sector), name)
    if not os.path.isfile(filename):
        print('Downloading: ' + filename)
        try:
            urllib.request.urlretrieve(link, filename)
        except Exception as inst:
            print(inst)
            print('  Encountered unknown error. Continuing.')
# Out:
# Downloading: ./documents/Corporate-Transportation/Alpha%20Trains_External%20Review%20Report.pdf
# Downloading: ./documents/Corporate-Transportation/Ferrovie_External%20Review%20Report.pdf
# Downloading: ./documents/Corporate-Transportation/Volkswagen_External%20Review%20Report%202020.pdf

# %% [markdown]
# # Run Questions

# %%
from tqdm.notebook import tqdm_notebook

# %%
queries = [
    "what did the use of proceeds finance?",
    "What are the eligible categories for the use of proceeds?",
]

# %%
# dataframe to hold results
df_test = pd.DataFrame(columns=["Sector", "Company", "Query", "Method"]+["Passage {}".format(i+1) for i in range(10)])
df_test
# Out:
# Empty DataFrame
# Columns: [Company, Sector, Query, Method, Passage 1, Passage 2, Passage 3, Passage 4, Passage 5, Passage 6, Passage 7, Passage 8, Passage 9, Passage 10]
# Index: []

# %%
reranker = Reranker()
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=1841.0, style=ProgressStyle(description…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=891691413.0, style=ProgressStyle(descri…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=1199.0, style=ProgressStyle(description…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=791656.0, style=ProgressStyle(descripti…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=1389353.0, style=ProgressStyle(descript…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=314.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=1340665848.0, style=ProgressStyle(descr…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=571.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=231508.0, style=ProgressStyle(descripti…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=28.0, style=ProgressStyle(description_w…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=466062.0, style=ProgressStyle(descripti…

# %%
bm25_count = 20
reranked_count = 10

# %%
for sector in tqdm_notebook(sectors):
  # Run retrieval and QA models over specificed SPO documents.
  for company in tqdm_notebook(sector_name2url[sector].keys()):
    # Extract PDF
    print(company)
    filename = "documents/{}/{}".format(sector,company)
    reader = Reader(filename)
    reader.extract_pdf()
    # Iterate through query, question pairs 
    for query in queries:
      # Get BM25 rankings
      try:
        texts = reader.get_ranked_texts([query], n=bm25_count)
      # No answers.
      except IndexError:
        print("No Results: {}\n       Query: {}".format(company, query))
        break
      for method in ["T5", "BERT"]:
        # Rerank
        reranked = reranker.rerank([query], texts, method=method)
        reranked = [item for item in reranked if len(item.text.strip())>0]
        reranked = reranked[:reranked_count]
        # Get text from pygaggle obj.
        reranked = [item.text for item in reranked]
        # Pad reranked to 10 entries.
        reranked += ["None"] * (10 - len(reranked))

        df_test.loc[len(df_test)] = [sector, company, query, method] + reranked
# Out:
# HBox(children=(FloatProgress(value=0.0, max=3.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# 2022-08-25 12:35:23 [WARNING] _utils:  impossible to decode XFormObject /Meta29
# 2022-08-25 12:35:23 [WARNING] _utils:  impossible to decode XFormObject /Meta30
# 2022-08-25 12:35:23 [WARNING] _utils:  impossible to decode XFormObject /Meta31
# 2022-08-25 12:35:23 [WARNING] _utils:  impossible to decode XFormObject /Meta32
# Blackstone_External%20Review%20Report.pdf
# /usr/local/lib/python3.7/dist-packages/transformers/models/t5/tokenization_t5.py:173: UserWarning: This sequence already has </s>. In future versions this behavior may lead to duplicated eos tokens being added.
#   f"This sequence already has {self.eos_token}. In future versions this behavior may lead to duplicated eos tokens being added."
# Castellum_External%20Review%20Report.pdf
# 2022-08-25 12:40:49 [WARNING] _utils:  impossible to decode XFormObject /Meta31
# 2022-08-25 12:40:49 [WARNING] _utils:  impossible to decode XFormObject /Meta32
# 2022-08-25 12:40:49 [WARNING] _utils:  impossible to decode XFormObject /Meta33
# 2022-08-25 12:40:49 [WARNING] _utils:  impossible to decode XFormObject /Meta34
# Cibus_External%20Review%20Report.pdf
# 2022-08-25 12:40:50 [WARNING] _utils:  impossible to decode XFormObject /Meta36
# 2022-08-25 12:40:50 [WARNING] _utils:  impossible to decode XFormObject /Meta36
# 2022-08-25 12:40:50 [WARNING] _utils:  impossible to decode XFormObject /Meta36
# 2022-08-25 12:40:50 [WARNING] _utils:  impossible to decode XFormObject /Meta36
# 2022-08-25 12:40:50 [WARNING] _utils:  impossible to decode XFormObject /Meta36
# 2022-08-25 12:40:50 [WARNING] _utils:  impossible to decode XFormObject /Meta36
# 2022-08-25 12:40:50 [WARNING] _utils:  impossible to decode XFormObject /Meta36
# 2022-08-25 12:40:50 [WARNING] _utils:  impossible to decode XFormObject /Meta36
# 2022-08-25 12:40:50 [WARNING] _utils:  impossible to decode XFormObject /Meta36
# 2022-08-25 12:40:51 [WARNING] _utils:  impossible to decode XFormObject /Meta36
# 2022-08-25 12:40:51 [WARNING] _utils:  impossible to decode XFormObject /Meta36
# 2022-08-25 12:40:51 [WARNING] _utils:  impossible to decode XFormObject /Meta36
# 2022-08-25 12:40:51 [WARNING] _utils:  impossible to decode XFormObject /Meta36
# 2022-08-25 12:40:51 [WARNING] _utils:  impossible to decode XFormObject /Meta36
# 2022-08-25 12:44:30 [WARNING] _utils:  impossible to decode XFormObject /Meta27
# 2022-08-25 12:44:30 [WARNING] _utils:  impossible to decode XFormObject /Meta28
# 2022-08-25 12:44:30 [WARNING] _utils:  impossible to decode XFormObject /Meta29
# 2022-08-25 12:44:30 [WARNING] _utils:  impossible to decode XFormObject /Meta30
# CTP_External%20Review%20Report.pdf
# 2022-08-25 12:44:30 [WARNING] _utils:  impossible to decode XFormObject /Meta32
# 2022-08-25 12:44:30 [WARNING] _utils:  impossible to decode XFormObject /Meta32
# 2022-08-25 12:44:30 [WARNING] _utils:  impossible to decode XFormObject /Meta32
# 2022-08-25 12:44:31 [WARNING] _utils:  impossible to decode XFormObject /Meta32
# 2022-08-25 12:44:31 [WARNING] _utils:  impossible to decode XFormObject /Meta32
# 2022-08-25 12:44:31 [WARNING] _utils:  impossible to decode XFormObject /Meta32
# 2022-08-25 12:44:31 [WARNING] _utils:  impossible to decode XFormObject /Meta32
# 2022-08-25 12:44:31 [WARNING] _utils:  impossible to decode XFormObject /Meta32
# 2022-08-25 12:44:31 [WARNING] _utils:  impossible to decode XFormObject /Meta32
# 2022-08-25 12:44:31 [WARNING] _utils:  impossible to decode XFormObject /Meta32
# 2022-08-25 12:44:31 [WARNING] _utils:  impossible to decode XFormObject /Meta32
# 2022-08-25 12:44:31 [WARNING] _utils:  impossible to decode XFormObject /Meta32
# 2022-08-25 12:44:31 [WARNING] _utils:  impossible to decode XFormObject /Meta32
# 2022-08-25 12:48:21 [WARNING] _utils:  impossible to decode XFormObject /Meta28
# 2022-08-25 12:48:21 [WARNING] _utils:  impossible to decode XFormObject /Meta29
# 2022-08-25 12:48:21 [WARNING] _utils:  impossible to decode XFormObject /Meta30
# 2022-08-25 12:48:21 [WARNING] _utils:  impossible to decode XFormObject /Meta31
# Deutsche%20Wohnen_External%20Review%20Report.pdf
# 2022-08-25 12:52:08 [WARNING] _utils:  impossible to decode XFormObject /Meta30
# 2022-08-25 12:52:08 [WARNING] _utils:  impossible to decode XFormObject /Meta31
# 2022-08-25 12:52:08 [WARNING] _utils:  impossible to decode XFormObject /Meta32
# 2022-08-25 12:52:08 [WARNING] _utils:  impossible to decode XFormObject /Meta33
# Globalworth_External%20Review%20Report.pdf
# 2022-08-25 12:52:08 [WARNING] _utils:  impossible to decode XFormObject /Meta35
# 2022-08-25 12:52:08 [WARNING] _utils:  impossible to decode XFormObject /Meta35
# 2022-08-25 12:52:08 [WARNING] _utils:  impossible to decode XFormObject /Meta35
# 2022-08-25 12:52:08 [WARNING] _utils:  impossible to decode XFormObject /Meta35
# 2022-08-25 12:52:08 [WARNING] _utils:  impossible to decode XFormObject /Meta35
# 2022-08-25 12:52:09 [WARNING] _utils:  impossible to decode XFormObject /Meta35
# 2022-08-25 12:52:09 [WARNING] _utils:  impossible to decode XFormObject /Meta35
# 2022-08-25 12:52:09 [WARNING] _utils:  impossible to decode XFormObject /Meta35
# 2022-08-25 12:52:09 [WARNING] _utils:  impossible to decode XFormObject /Meta35
# 2022-08-25 12:52:09 [WARNING] _utils:  impossible to decode XFormObject /Meta35
# 2022-08-25 12:52:09 [WARNING] _utils:  impossible to decode XFormObject /Meta35
# 2022-08-25 12:52:09 [WARNING] _utils:  impossible to decode XFormObject /Meta35
# 2022-08-25 12:52:09 [WARNING] _utils:  impossible to decode XFormObject /Meta35
# 2022-08-25 12:52:09 [WARNING] _utils:  impossible to decode XFormObject /Meta35
# ICADE_External%20Review%20Report.pdf
# 2022-08-25 12:57:23 [WARNING] _utils:  impossible to decode XFormObject /Meta29
# 2022-08-25 12:57:23 [WARNING] _utils:  impossible to decode XFormObject /Meta30
# 2022-08-25 12:57:23 [WARNING] _utils:  impossible to decode XFormObject /Meta31
# 2022-08-25 12:57:23 [WARNING] _utils:  impossible to decode XFormObject /Meta32
# Johnson_External%20Review%20Report.pdf
# 2022-08-25 12:57:23 [WARNING] _utils:  impossible to decode XFormObject /Meta34
# 2022-08-25 12:57:23 [WARNING] _utils:  impossible to decode XFormObject /Meta34
# 2022-08-25 12:57:23 [WARNING] _utils:  impossible to decode XFormObject /Meta34
# 2022-08-25 12:57:23 [WARNING] _utils:  impossible to decode XFormObject /Meta34
# 2022-08-25 12:57:24 [WARNING] _utils:  impossible to decode XFormObject /Meta34
# 2022-08-25 12:57:24 [WARNING] _utils:  impossible to decode XFormObject /Meta34
# 2022-08-25 12:57:24 [WARNING] _utils:  impossible to decode XFormObject /Meta34
# 2022-08-25 12:57:24 [WARNING] _utils:  impossible to decode XFormObject /Meta34
# 2022-08-25 12:57:24 [WARNING] _utils:  impossible to decode XFormObject /Meta34
# 2022-08-25 12:57:24 [WARNING] _utils:  impossible to decode XFormObject /Meta34
# 2022-08-25 12:57:24 [WARNING] _utils:  impossible to decode XFormObject /Meta34
# 2022-08-25 12:57:24 [WARNING] _utils:  impossible to decode XFormObject /Meta34
# 2022-08-25 12:57:24 [WARNING] _utils:  impossible to decode XFormObject /Meta34
# 2022-08-25 12:57:24 [WARNING] _utils:  impossible to decode XFormObject /Meta34
# 2022-08-25 12:57:24 [WARNING] _utils:  impossible to decode XFormObject /Meta34
# Specialfastigheter-External%20Review%20Report.pdf
# 2022-08-25 13:04:13 [WARNING] _utils:  impossible to decode XFormObject /Meta31
# 2022-08-25 13:04:13 [WARNING] _utils:  impossible to decode XFormObject /Meta32
# 2022-08-25 13:04:13 [WARNING] _utils:  impossible to decode XFormObject /Meta33
# 2022-08-25 13:04:13 [WARNING] _utils:  impossible to decode XFormObject /Meta34
# tritax-eurobox_External%20Review%20Report.pdf
# Vesteda_External%20Review%20Report.pdf
# 2022-08-25 13:08:29 [WARNING] _utils:  impossible to decode XFormObject /Meta32
# 2022-08-25 13:08:29 [WARNING] _utils:  impossible to decode XFormObject /Meta33
# 2022-08-25 13:08:29 [WARNING] _utils:  impossible to decode XFormObject /Meta34
# 2022-08-25 13:08:29 [WARNING] _utils:  impossible to decode XFormObject /Meta35
# 2022-08-25 13:08:29 [WARNING] _utils:  impossible to decode XFormObject /Meta36
# 2022-08-25 13:08:30 [WARNING] _utils:  impossible to decode XFormObject /Meta32
# 2022-08-25 13:08:30 [WARNING] _utils:  impossible to decode XFormObject /Meta32
# 2022-08-25 13:08:30 [WARNING] _utils:  impossible to decode XFormObject /Meta32
# 2022-08-25 13:08:30 [WARNING] _utils:  impossible to decode XFormObject /Meta32
# 2022-08-25 13:08:30 [WARNING] _utils:  impossible to decode XFormObject /Meta32
# 2022-08-25 13:08:30 [WARNING] _utils:  impossible to decode XFormObject /Meta32
# 2022-08-25 13:08:30 [WARNING] _utils:  impossible to decode XFormObject /Meta32
# 2022-08-25 13:08:30 [WARNING] _utils:  impossible to decode XFormObject /Meta32
# 2022-08-25 13:08:30 [WARNING] _utils:  impossible to decode XFormObject /Meta32
# 2022-08-25 13:08:30 [WARNING] _utils:  impossible to decode XFormObject /Meta32
# 2022-08-25 13:08:30 [WARNING] _utils:  impossible to decode XFormObject /Meta32
# 2022-08-25 13:08:30 [WARNING] _utils:  impossible to decode XFormObject /Meta32
# 2022-08-25 13:08:30 [WARNING] _utils:  impossible to decode XFormObject /Meta32
# 2022-08-25 13:12:01 [WARNING] _utils:  impossible to decode XFormObject /Meta28
# 2022-08-25 13:12:01 [WARNING] _utils:  impossible to decode XFormObject /Meta29
# 2022-08-25 13:12:01 [WARNING] _utils:  impossible to decode XFormObject /Meta30
# 2022-08-25 13:12:01 [WARNING] _utils:  impossible to decode XFormObject /Meta31
# V%C3%ADa%20C%C3%A9lere_External%20Review%20Report.pdf
# Vonovia_External%20Review%20Report.pdf
# 2022-08-25 13:16:15 [WARNING] _utils:  impossible to decode XFormObject /Meta28
# 2022-08-25 13:16:15 [WARNING] _utils:  impossible to decode XFormObject /Meta29
# 2022-08-25 13:16:15 [WARNING] _utils:  impossible to decode XFormObject /Meta30
# 2022-08-25 13:16:15 [WARNING] _utils:  impossible to decode XFormObject /Meta31
# 2022-08-25 13:20:06 [WARNING] _utils:  impossible to decode XFormObject /Meta30
# 2022-08-25 13:20:06 [WARNING] _utils:  impossible to decode XFormObject /Meta31
# 2022-08-25 13:20:06 [WARNING] _utils:  impossible to decode XFormObject /Meta32
# 2022-08-25 13:20:06 [WARNING] _utils:  impossible to decode XFormObject /Meta33
# Xior_External%20Review%20Report.pdf
# 2022-08-25 13:20:06 [WARNING] _utils:  impossible to decode XFormObject /Meta35
# 2022-08-25 13:20:06 [WARNING] _utils:  impossible to decode XFormObject /Meta35
# 2022-08-25 13:20:06 [WARNING] _utils:  impossible to decode XFormObject /Meta35
# 2022-08-25 13:20:06 [WARNING] _utils:  impossible to decode XFormObject /Meta35
# 2022-08-25 13:20:07 [WARNING] _utils:  impossible to decode XFormObject /Meta35
# 2022-08-25 13:20:07 [WARNING] _utils:  impossible to decode XFormObject /Meta35
# 2022-08-25 13:20:07 [WARNING] _utils:  impossible to decode XFormObject /Meta35
# 2022-08-25 13:20:07 [WARNING] _utils:  impossible to decode XFormObject /Meta35
# 2022-08-25 13:20:07 [WARNING] _utils:  impossible to decode XFormObject /Meta35
# 2022-08-25 13:20:07 [WARNING] _utils:  impossible to decode XFormObject /Meta35
# 2022-08-25 13:20:07 [WARNING] _utils:  impossible to decode XFormObject /Meta35
# 2022-08-25 13:20:07 [WARNING] _utils:  impossible to decode XFormObject /Meta35
# 2022-08-25 13:20:07 [WARNING] _utils:  impossible to decode XFormObject /Meta35
# HBox(children=(FloatProgress(value=0.0, max=12.0), HTML(value='')))
# Baseload%20Capital_External%20Review%20Report.pdf
# 2022-08-25 13:23:02 [WARNING] _utils:  impossible to decode XFormObject /Meta26
# 2022-08-25 13:23:02 [WARNING] _utils:  impossible to decode XFormObject /Meta27
# 2022-08-25 13:23:02 [WARNING] _utils:  impossible to decode XFormObject /Meta28
# 2022-08-25 13:23:02 [WARNING] _utils:  impossible to decode XFormObject /Meta29
# 2022-08-25 13:23:02 [WARNING] _utils:  impossible to decode XFormObject /Meta30
# 2022-08-25 13:23:02 [WARNING] _utils:  impossible to decode XFormObject /Meta26
# 2022-08-25 13:23:02 [WARNING] _utils:  impossible to decode XFormObject /Meta26
# 2022-08-25 13:23:02 [WARNING] _utils:  impossible to decode XFormObject /Meta26
# 2022-08-25 13:23:02 [WARNING] _utils:  impossible to decode XFormObject /Meta26
# 2022-08-25 13:23:02 [WARNING] _utils:  impossible to decode XFormObject /Meta26
# 2022-08-25 13:23:02 [WARNING] _utils:  impossible to decode XFormObject /Meta26
# 2022-08-25 13:23:02 [WARNING] _utils:  impossible to decode XFormObject /Meta26
# 2022-08-25 13:23:02 [WARNING] _utils:  impossible to decode XFormObject /Meta26
# 2022-08-25 13:23:02 [WARNING] _utils:  impossible to decode XFormObject /Meta26
# 2022-08-25 13:23:02 [WARNING] _utils:  impossible to decode XFormObject /Meta26
# 2022-08-25 13:23:02 [WARNING] _utils:  impossible to decode XFormObject /Meta26
# 2022-08-25 13:23:02 [WARNING] _utils:  impossible to decode XFormObject /Meta26
# 2022-08-25 13:23:03 [WARNING] _utils:  impossible to decode XFormObject /Meta26
# 2022-08-25 13:25:52 [WARNING] _utils:  impossible to decode XFormObject /Meta30
# 2022-08-25 13:25:52 [WARNING] _utils:  impossible to decode XFormObject /Meta31
# 2022-08-25 13:25:52 [WARNING] _utils:  impossible to decode XFormObject /Meta32
# 2022-08-25 13:25:52 [WARNING] _utils:  impossible to decode XFormObject /Meta33
# 2022-08-25 13:25:52 [WARNING] _utils:  impossible to decode XFormObject /Meta34
# E.ON_External%20Review%20Report.pdf
# 2022-08-25 13:25:52 [WARNING] _utils:  impossible to decode XFormObject /Meta30
# 2022-08-25 13:25:52 [WARNING] _utils:  impossible to decode XFormObject /Meta30
# 2022-08-25 13:25:53 [WARNING] _utils:  impossible to decode XFormObject /Meta30
# 2022-08-25 13:25:53 [WARNING] _utils:  impossible to decode XFormObject /Meta30
# 2022-08-25 13:25:53 [WARNING] _utils:  impossible to decode XFormObject /Meta30
# 2022-08-25 13:25:53 [WARNING] _utils:  impossible to decode XFormObject /Meta30
# 2022-08-25 13:25:53 [WARNING] _utils:  impossible to decode XFormObject /Meta30
# 2022-08-25 13:25:53 [WARNING] _utils:  impossible to decode XFormObject /Meta30
# 2022-08-25 13:25:53 [WARNING] _utils:  impossible to decode XFormObject /Meta30
# 2022-08-25 13:25:53 [WARNING] _utils:  impossible to decode XFormObject /Meta30
# 2022-08-25 13:25:53 [WARNING] _utils:  impossible to decode XFormObject /Meta30
# 2022-08-25 13:25:54 [WARNING] _utils:  impossible to decode XFormObject /Meta30
# 2022-08-25 13:25:54 [WARNING] _utils:  impossible to decode XFormObject /Meta30
# 2022-08-25 13:25:54 [WARNING] _utils:  impossible to decode XFormObject /Meta30
# 2022-08-25 13:29:03 [WARNING] _utils:  impossible to decode XFormObject /Meta36
# 2022-08-25 13:29:03 [WARNING] _utils:  impossible to decode XFormObject /Meta37
# 2022-08-25 13:29:03 [WARNING] _utils:  impossible to decode XFormObject /Meta38
# 2022-08-25 13:29:03 [WARNING] _utils:  impossible to decode XFormObject /Meta39
# E.ON_External%20Review%20Report%202021.pdf
# 2022-08-25 13:33:19 [WARNING] _utils:  impossible to decode XFormObject /Meta28
# 2022-08-25 13:33:19 [WARNING] _utils:  impossible to decode XFormObject /Meta29
# 2022-08-25 13:33:19 [WARNING] _utils:  impossible to decode XFormObject /Meta30
# 2022-08-25 13:33:19 [WARNING] _utils:  impossible to decode XFormObject /Meta31
# 2022-08-25 13:33:19 [WARNING] _utils:  impossible to decode XFormObject /Meta32
# ESB_External%20Review%20Report.pdf
# 2022-08-25 13:33:19 [WARNING] _utils:  impossible to decode XFormObject /Meta28
# 2022-08-25 13:33:19 [WARNING] _utils:  impossible to decode XFormObject /Meta28
# 2022-08-25 13:33:20 [WARNING] _utils:  impossible to decode XFormObject /Meta28
# 2022-08-25 13:33:20 [WARNING] _utils:  impossible to decode XFormObject /Meta28
# 2022-08-25 13:33:20 [WARNING] _utils:  impossible to decode XFormObject /Meta28
# 2022-08-25 13:33:20 [WARNING] _utils:  impossible to decode XFormObject /Meta28
# 2022-08-25 13:33:20 [WARNING] _utils:  impossible to decode XFormObject /Meta28
# 2022-08-25 13:33:20 [WARNING] _utils:  impossible to decode XFormObject /Meta28
# 2022-08-25 13:33:20 [WARNING] _utils:  impossible to decode XFormObject /Meta28
# 2022-08-25 13:33:21 [WARNING] _utils:  impossible to decode XFormObject /Meta28
# 2022-08-25 13:33:21 [WARNING] _utils:  impossible to decode XFormObject /Meta28
# 2022-08-25 13:33:21 [WARNING] _utils:  impossible to decode XFormObject /Meta28
# 2022-08-25 13:33:21 [WARNING] _utils:  impossible to decode XFormObject /Meta28
# 2022-08-25 13:33:21 [WARNING] _utils:  impossible to decode XFormObject /Meta28
# 2022-08-25 13:33:21 [WARNING] _utils:  impossible to decode XFormObject /Meta28
# 2022-08-25 13:33:21 [WARNING] _utils:  impossible to decode XFormObject /Meta28
# innogy_External%20Review%20Report.pdf
# 2022-08-25 13:38:39 [WARNING] _utils:  impossible to decode XFormObject /Meta28
# 2022-08-25 13:38:39 [WARNING] _utils:  impossible to decode XFormObject /Meta29
# 2022-08-25 13:38:39 [WARNING] _utils:  impossible to decode XFormObject /Meta30
# 2022-08-25 13:38:39 [WARNING] _utils:  impossible to decode XFormObject /Meta31
# 2022-08-25 13:38:39 [WARNING] _utils:  impossible to decode XFormObject /Meta32
# Midsummer_External%20Review%20Report.pdf
# 2022-08-25 13:38:39 [WARNING] _utils:  impossible to decode XFormObject /Meta28
# 2022-08-25 13:38:39 [WARNING] _utils:  impossible to decode XFormObject /Meta28
# 2022-08-25 13:38:39 [WARNING] _utils:  impossible to decode XFormObject /Meta28
# 2022-08-25 13:38:39 [WARNING] _utils:  impossible to decode XFormObject /Meta28
# 2022-08-25 13:38:39 [WARNING] _utils:  impossible to decode XFormObject /Meta28
# 2022-08-25 13:38:39 [WARNING] _utils:  impossible to decode XFormObject /Meta28
# 2022-08-25 13:38:39 [WARNING] _utils:  impossible to decode XFormObject /Meta28
# 2022-08-25 13:38:40 [WARNING] _utils:  impossible to decode XFormObject /Meta28
# 2022-08-25 13:38:40 [WARNING] _utils:  impossible to decode XFormObject /Meta28
# 2022-08-25 13:38:40 [WARNING] _utils:  impossible to decode XFormObject /Meta28
# 2022-08-25 13:38:40 [WARNING] _utils:  impossible to decode XFormObject /Meta28
# 2022-08-25 13:38:40 [WARNING] _utils:  impossible to decode XFormObject /Meta28
# Landsvirkjun-External%20Review%20Report.pdf
# 2022-08-25 13:44:34 [WARNING] _utils:  impossible to decode XFormObject /Meta32
# 2022-08-25 13:44:34 [WARNING] _utils:  impossible to decode XFormObject /Meta33
# 2022-08-25 13:44:34 [WARNING] _utils:  impossible to decode XFormObject /Meta34
# 2022-08-25 13:44:34 [WARNING] _utils:  impossible to decode XFormObject /Meta35
# neutral%20fuels_External%20Review%20Report.pdf
# Repower_External%20Review%20Report.pdf
# 2022-08-25 13:50:39 [WARNING] _utils:  impossible to decode XFormObject /Meta27
# 2022-08-25 13:50:39 [WARNING] _utils:  impossible to decode XFormObject /Meta28
# 2022-08-25 13:50:39 [WARNING] _utils:  impossible to decode XFormObject /Meta29
# 2022-08-25 13:50:39 [WARNING] _utils:  impossible to decode XFormObject /Meta30
# RWE_External%20Review%20Report.pdf
# 2022-08-25 13:50:39 [WARNING] _utils:  impossible to decode XFormObject /Meta32
# 2022-08-25 13:50:39 [WARNING] _utils:  impossible to decode XFormObject /Meta32
# 2022-08-25 13:50:39 [WARNING] _utils:  impossible to decode XFormObject /Meta32
# 2022-08-25 13:50:39 [WARNING] _utils:  impossible to decode XFormObject /Meta32
# 2022-08-25 13:50:39 [WARNING] _utils:  impossible to decode XFormObject /Meta32
# 2022-08-25 13:50:40 [WARNING] _utils:  impossible to decode XFormObject /Meta32
# 2022-08-25 13:50:40 [WARNING] _utils:  impossible to decode XFormObject /Meta32
# 2022-08-25 13:50:40 [WARNING] _utils:  impossible to decode XFormObject /Meta32
# 2022-08-25 13:50:40 [WARNING] _utils:  impossible to decode XFormObject /Meta32
# 2022-08-25 13:50:40 [WARNING] _utils:  impossible to decode XFormObject /Meta32
# 2022-08-25 13:50:40 [WARNING] _utils:  impossible to decode XFormObject /Meta32
# 2022-08-25 13:50:40 [WARNING] _utils:  impossible to decode XFormObject /Meta32
# Synthesis%20Analytics_External%20Review%20Report.pdf
# 2022-08-25 13:54:10 [WARNING] _utils:  impossible to decode XFormObject /Meta27
# 2022-08-25 13:54:10 [WARNING] _utils:  impossible to decode XFormObject /Meta28
# 2022-08-25 13:54:10 [WARNING] _utils:  impossible to decode XFormObject /Meta29
# 2022-08-25 13:54:10 [WARNING] _utils:  impossible to decode XFormObject /Meta30
# 2022-08-25 13:54:10 [WARNING] _utils:  impossible to decode XFormObject /Meta32
# 2022-08-25 13:54:10 [WARNING] _utils:  impossible to decode XFormObject /Meta32
# 2022-08-25 13:54:10 [WARNING] _utils:  impossible to decode XFormObject /Meta32
# 2022-08-25 13:54:10 [WARNING] _utils:  impossible to decode XFormObject /Meta32
# 2022-08-25 13:54:10 [WARNING] _utils:  impossible to decode XFormObject /Meta32
# 2022-08-25 13:54:10 [WARNING] _utils:  impossible to decode XFormObject /Meta32
# 2022-08-25 13:54:10 [WARNING] _utils:  impossible to decode XFormObject /Meta32
# 2022-08-25 13:54:10 [WARNING] _utils:  impossible to decode XFormObject /Meta32
# 2022-08-25 13:54:10 [WARNING] _utils:  impossible to decode XFormObject /Meta32
# 2022-08-25 13:54:11 [WARNING] _utils:  impossible to decode XFormObject /Meta32
# 2022-08-25 13:54:11 [WARNING] _utils:  impossible to decode XFormObject /Meta32
# 2022-08-25 13:54:11 [WARNING] _utils:  impossible to decode XFormObject /Meta32
# 2022-08-25 13:54:11 [WARNING] _utils:  impossible to decode XFormObject /Meta32
# 2022-08-25 13:54:11 [WARNING] _utils:  impossible to decode XFormObject /Meta32
# 2022-08-25 13:54:11 [WARNING] _utils:  impossible to decode XFormObject /Meta32
# Water%20Wheel_External%20Review%20Report.pdf
# 2022-08-25 13:57:35 [WARNING] _utils:  impossible to decode XFormObject /Meta38
# 2022-08-25 13:57:35 [WARNING] _utils:  impossible to decode XFormObject /Meta39
# 2022-08-25 13:57:35 [WARNING] _utils:  impossible to decode XFormObject /Meta40
# 2022-08-25 13:57:35 [WARNING] _utils:  impossible to decode XFormObject /Meta41
# 2022-08-25 13:57:35 [WARNING] _utils:  impossible to decode XFormObject /Meta43
# 2022-08-25 13:57:35 [WARNING] _utils:  impossible to decode XFormObject /Meta43
# 2022-08-25 13:57:35 [WARNING] _utils:  impossible to decode XFormObject /Meta43
# 2022-08-25 13:57:36 [WARNING] _utils:  impossible to decode XFormObject /Meta43
# 2022-08-25 13:57:36 [WARNING] _utils:  impossible to decode XFormObject /Meta43
# 2022-08-25 13:57:36 [WARNING] _utils:  impossible to decode XFormObject /Meta43
# 2022-08-25 13:57:36 [WARNING] _utils:  impossible to decode XFormObject /Meta43
# 2022-08-25 13:57:36 [WARNING] _utils:  impossible to decode XFormObject /Meta43
# 2022-08-25 13:57:36 [WARNING] _utils:  impossible to decode XFormObject /Meta43
# 2022-08-25 13:57:36 [WARNING] _utils:  impossible to decode XFormObject /Meta43
# 2022-08-25 13:57:36 [WARNING] _utils:  impossible to decode XFormObject /Meta43
# 2022-08-25 13:57:36 [WARNING] _utils:  impossible to decode XFormObject /Meta43
# 2022-08-25 13:57:36 [WARNING] _utils:  impossible to decode XFormObject /Meta43
# HBox(children=(FloatProgress(value=0.0, max=3.0), HTML(value='')))
# Alpha%20Trains_External%20Review%20Report.pdf
# Ferrovie_External%20Review%20Report.pdf
# Volkswagen_External%20Review%20Report%202020.pdf
# 2022-08-25 14:04:47 [WARNING] _utils:  impossible to decode XFormObject /Meta31
# 2022-08-25 14:04:47 [WARNING] _utils:  impossible to decode XFormObject /Meta32
# 2022-08-25 14:04:47 [WARNING] _utils:  impossible to decode XFormObject /Meta33
# 2022-08-25 14:04:47 [WARNING] _utils:  impossible to decode XFormObject /Meta34
# 2022-08-25 14:04:47 [WARNING] _utils:  impossible to decode XFormObject /Meta36
# 2022-08-25 14:04:47 [WARNING] _utils:  impossible to decode XFormObject /Meta36
# 2022-08-25 14:04:47 [WARNING] _utils:  impossible to decode XFormObject /Meta36
# 2022-08-25 14:04:47 [WARNING] _utils:  impossible to decode XFormObject /Meta36
# 2022-08-25 14:04:47 [WARNING] _utils:  impossible to decode XFormObject /Meta36
# 2022-08-25 14:04:47 [WARNING] _utils:  impossible to decode XFormObject /Meta36
# 2022-08-25 14:04:47 [WARNING] _utils:  impossible to decode XFormObject /Meta36
# 2022-08-25 14:04:47 [WARNING] _utils:  impossible to decode XFormObject /Meta36
# 2022-08-25 14:04:47 [WARNING] _utils:  impossible to decode XFormObject /Meta36
# 2022-08-25 14:04:48 [WARNING] _utils:  impossible to decode XFormObject /Meta36
# 2022-08-25 14:04:48 [WARNING] _utils:  impossible to decode XFormObject /Meta36
# 2022-08-25 14:04:48 [WARNING] _utils:  impossible to decode XFormObject /Meta36
# 2022-08-25 14:04:48 [WARNING] _utils:  impossible to decode XFormObject /Meta36
# 2022-08-25 14:04:48 [WARNING] _utils:  impossible to decode XFormObject /Meta36

# %%
df_test_q1 = df_test.loc[
    (df_test["Query"] == queries[0])
] 
df_test_q1.reset_index(drop=True, inplace=True)

# %%
from IPython.display import clear_output 

# List to store inputs.
full_list = []

# Cell holds functionality to iterate through dataframe and print all 10 retrieved passages.
# for the purpose of hand labelling correctly relevant passages.
for i in range(len(df_test_q1)):
  for j, column in enumerate(df_test_q1.iloc[i]):
    if j > 3:
      print("-"*40, "{}".format(j-3), "-"*40)
      print(column)
      print("\n\n")
  x = input()
  x = [int(n) for n in x.split()]
  full_list.append(x)

  clear_output()

# %%
df_bert = df_test_q1.loc[
    (df_test["Method"] == "BERT")
] 
df_t5 = df_test_q1.loc[
    (df_test["Method"] == "T5")
]

# %%
df_test_q1
# Out:
#                                               Company  \
# 0           Blackstone_External%20Review%20Report.pdf
# 1           Blackstone_External%20Review%20Report.pdf
# 2            Castellum_External%20Review%20Report.pdf
# 3            Castellum_External%20Review%20Report.pdf
# 4                Cibus_External%20Review%20Report.pdf
# 5                Cibus_External%20Review%20Report.pdf
# 6                  CTP_External%20Review%20Report.pdf
# 7                  CTP_External%20Review%20Report.pdf
# 8    Deutsche%20Wohnen_External%20Review%20Report.pdf
# 9    Deutsche%20Wohnen_External%20Review%20Report.pdf
# 10         Globalworth_External%20Review%20Report.pdf
# 11         Globalworth_External%20Review%20Report.pdf
# 12               ICADE_External%20Review%20Report.pdf
# 13               ICADE_External%20Review%20Report.pdf
# 14             Johnson_External%20Review%20Report.pdf
# 15             Johnson_External%20Review%20Report.pdf
# 16  Specialfastigheter-External%20Review%20Report.pdf
# 17  Specialfastigheter-External%20Review%20Report.pdf
# 18      tritax-eurobox_External%20Review%20Report.pdf
# 19      tritax-eurobox_External%20Review%20Report.pdf
# 20             Vesteda_External%20Review%20Report.pdf
# 21             Vesteda_External%20Review%20Report.pdf
# 22  V%C3%ADa%20C%C3%A9lere_External%20Review%20Rep...
# 23  V%C3%ADa%20C%C3%A9lere_External%20Review%20Rep...
# 24             Vonovia_External%20Review%20Report.pdf
# 25             Vonovia_External%20Review%20Report.pdf
# 26                Xior_External%20Review%20Report.pdf
# 27                Xior_External%20Review%20Report.pdf
# 28  Baseload%20Capital_External%20Review%20Report.pdf
# 29  Baseload%20Capital_External%20Review%20Report.pdf
# 30                E.ON_External%20Review%20Report.pdf
# 31                E.ON_External%20Review%20Report.pdf
# 32         E.ON_External%20Review%20Report%202021.pdf
# 33         E.ON_External%20Review%20Report%202021.pdf
# 34                 ESB_External%20Review%20Report.pdf
# 35                 ESB_External%20Review%20Report.pdf
# 36              innogy_External%20Review%20Report.pdf
# 37              innogy_External%20Review%20Report.pdf
# 38           Midsummer_External%20Review%20Report.pdf
# 39           Midsummer_External%20Review%20Report.pdf
# 40        Landsvirkjun-External%20Review%20Report.pdf
# 41        Landsvirkjun-External%20Review%20Report.pdf
# 42     neutral%20fuels_External%20Review%20Report.pdf
# 43     neutral%20fuels_External%20Review%20Report.pdf
# 44             Repower_External%20Review%20Report.pdf
# 45             Repower_External%20Review%20Report.pdf
# 46                 RWE_External%20Review%20Report.pdf
# 47                 RWE_External%20Review%20Report.pdf
# 48  Synthesis%20Analytics_External%20Review%20Repo...
# 49  Synthesis%20Analytics_External%20Review%20Repo...
# 50       Water%20Wheel_External%20Review%20Report.pdf
# 51       Water%20Wheel_External%20Review%20Report.pdf
# 52      Alpha%20Trains_External%20Review%20Report.pdf
# 53      Alpha%20Trains_External%20Review%20Report.pdf
# 54            Ferrovie_External%20Review%20Report.pdf
# 55            Ferrovie_External%20Review%20Report.pdf
# 56   Volkswagen_External%20Review%20Report%202020.pdf
# 57   Volkswagen_External%20Review%20Report%202020.pdf
#
#                       Sector                                  Query Method  \
# 0      Corporate-Real Estate  what did the use of proceeds finance?     T5
# 1      Corporate-Real Estate  what did the use of proceeds finance?   BERT
# 2      Corporate-Real Estate  what did the use of proceeds finance?     T5
# 3      Corporate-Real Estate  what did the use of proceeds finance?   BERT
# 4      Corporate-Real Estate  what did the use of proceeds finance?     T5
# 5      Corporate-Real Estate  what did the use of proceeds finance?   BERT
# 6      Corporate-Real Estate  what did the use of proceeds finance?     T5
# 7      Corporate-Real Estate  what did the use of proceeds finance?   BERT
# 8      Corporate-Real Estate  what did the use of proceeds finance?     T5
# 9      Corporate-Real Estate  what did the use of proceeds finance?   BERT
# 10     Corporate-Real Estate  what did the use of proceeds finance?     T5
# 11     Corporate-Real Estate  what did the use of proceeds finance?   BERT
# 12     Corporate-Real Estate  what did the use of proceeds finance?     T5
# 13     Corporate-Real Estate  what did the use of proceeds finance?   BERT
# 14     Corporate-Real Estate  what did the use of proceeds finance?     T5
# 15     Corporate-Real Estate  what did the use of proceeds finance?   BERT
# 16     Corporate-Real Estate  what did the use of proceeds finance?     T5
# 17     Corporate-Real Estate  what did the use of proceeds finance?   BERT
# 18     Corporate-Real Estate  what did the use of proceeds finance?     T5
# 19     Corporate-Real Estate  what did the use of proceeds finance?   BERT
# 20     Corporate-Real Estate  what did the use of proceeds finance?     T5
# 21     Corporate-Real Estate  what did the use of proceeds finance?   BERT
# 22     Corporate-Real Estate  what did the use of proceeds finance?     T5
# 23     Corporate-Real Estate  what did the use of proceeds finance?   BERT
# 24     Corporate-Real Estate  what did the use of proceeds finance?     T5
# 25     Corporate-Real Estate  what did the use of proceeds finance?   BERT
# 26     Corporate-Real Estate  what did the use of proceeds finance?     T5
# 27     Corporate-Real Estate  what did the use of proceeds finance?   BERT
# 28          Corporate-Energy  what did the use of proceeds finance?     T5
# 29          Corporate-Energy  what did the use of proceeds finance?   BERT
# 30          Corporate-Energy  what did the use of proceeds finance?     T5
# 31          Corporate-Energy  what did the use of proceeds finance?   BERT
# 32          Corporate-Energy  what did the use of proceeds finance?     T5
# 33          Corporate-Energy  what did the use of proceeds finance?   BERT
# 34          Corporate-Energy  what did the use of proceeds finance?     T5
# 35          Corporate-Energy  what did the use of proceeds finance?   BERT
# 36          Corporate-Energy  what did the use of proceeds finance?     T5
# 37          Corporate-Energy  what did the use of proceeds finance?   BERT
# 38          Corporate-Energy  what did the use of proceeds finance?     T5
# 39          Corporate-Energy  what did the use of proceeds finance?   BERT
# 40          Corporate-Energy  what did the use of proceeds finance?     T5
# 41          Corporate-Energy  what did the use of proceeds finance?   BERT
# 42          Corporate-Energy  what did the use of proceeds finance?     T5
# 43          Corporate-Energy  what did the use of proceeds finance?   BERT
# 44          Corporate-Energy  what did the use of proceeds finance?     T5
# 45          Corporate-Energy  what did the use of proceeds finance?   BERT
# 46          Corporate-Energy  what did the use of proceeds finance?     T5
# 47          Corporate-Energy  what did the use of proceeds finance?   BERT
# 48          Corporate-Energy  what did the use of proceeds finance?     T5
# 49          Corporate-Energy  what did the use of proceeds finance?   BERT
# 50          Corporate-Energy  what did the use of proceeds finance?     T5
# 51          Corporate-Energy  what did the use of proceeds finance?   BERT
# 52  Corporate-Transportation  what did the use of proceeds finance?     T5
# 53  Corporate-Transportation  what did the use of proceeds finance?   BERT
# 54  Corporate-Transportation  what did the use of proceeds finance?     T5
# 55  Corporate-Transportation  what did the use of proceeds finance?   BERT
# 56  Corporate-Transportation  what did the use of proceeds finance?     T5
# 57  Corporate-Transportation  what did the use of proceeds finance?   BERT
#
#                                             Passage 1  \
# 0   12  \nThe eligible categories for the use of p...
# 1   Use of proceeds reporting : \n☐ Project -by-pr...
# 2   2.3.1  Use of Proceeds  \nThe proceeds of the ...
# 3   Tracking of proceeds:  \n☒ Green Bond proceeds...
# 4   6 Conclusion   \nCibus  has developed the Cibu...
# 5   Where appropriate, please specify name and dat...
# 6   Conclusion  \nCTP  has developed the CTP Green...
# 7   11 Frequency:  \n☒ Annual  ☐ Semi -annual  \n☐...
# 8   Conclusion   \nDeutsche Wohnen  has developed ...
# 9   12 ☐ Linkage to individual bond(s)  ☐ Other (p...
# 10   \nConclusion   \nGlobalworth has developed th...
# 11  Frequency:  \n☒ Annual  ☐ Semi -annual  \n☐ Ot...
# 12    15 \nUse of proceeds categories as per GBP: ...
# 13  Use of proceeds reporting:  \n☐ Project -by-pr...
# 14  Conclusion   \nJCI has developed the Johnson C...
# 15  13 Information reported:  \n☒ Allocated amount...
# 16  Specialfastigheter has developed a Green Bond ...
# 17  Use of proceeds reporting:  \n☒ Project -by-pr...
# 18  11 The eligible categories for the use of proc...
# 19  13 Use of proceeds reporting : \n☐ Project -by...
# 20  Section 3. Detailed review  \nReviewers are en...
# 21  Frequency:  \n☒ Annual  ☐ Semi -annual  \n☐ Ot...
# 22   \nConclusion   \nVía Célere  has developed th...
# 23  10 Information reported:  \n☒ Allocated amou n...
# 24  Conclusion   \nVonovia  has developed the Vono...
# 25  13  SPECIFY OTHER EXTERNAL REVIEWS AVAILABLE, ...
# 26  Conclusion  \nXior  has developed the Xior Stu...
# 27  Information reported:  \n☒ Allocated amounts  ...
# 28  Section 3. Detailed review  \nReviewers are en...
# 29  Frequency:  \n☒ Annual  ☐ Semi -annual  \n☐ Ot...
# 30   \nConclusion  \nE.ON  SE has developed the E....
# 31  Frequency:  \n☒ Annual  ☐ Semi -annual  \n☐ Ot...
# 32  37 The eligible categories for the use of proc...
# 33   \nUse of proceeds reporting:  \n☐ Project -by...
# 34   Use of proceeds:  \n- The four use s of proc...
# 35  14  \nFrequency:  \n☒ Annual  ☐ Semi -annual  ...
# 36   \n 11 \nSection 3.  Detailed review  \n1. USE...
# 37  Use of proceeds reporting:  \n☒ Project -by-pr...
# 38  The  Framework is aligned with the four core c...
# 39  Frequency:  \n☒ Annual  ☐ Semi -annual  \n☐ Ot...
# 40    18 \nSection 3.  Detailed review  \n1. USE O...
# 41  Use of proceeds reporting:  \n☐ Project -by-pr...
# 42  9 Conclusion  \nNeutral Capital Finance PLC ha...
# 43  15 ☐ Verification / Audit  ☐ Rating  \n☐ Other...
# 44  1. USE OF PROCEEDS  \nOverall comment on secti...
# 45  Tracking of proceeds:  \n☒ Green Bond proceeds...
# 46  Sustainalytics is of the opinion that projects...
# 47  Frequency:  \n☒ Annual  ☐ Semi -annual  \n☐ Ot...
# 48  3 In addition, the Second -Party Opinion opine...
# 49  ROLE(S) OF REVIEW PROVIDER  \n☒ Consultancy (i...
# 50  8 Section 3. Detailed review  \nReviewer s are...
# 51  Frequency:  \n☒ Annual  ☐ Semi -annual  \n☐ Ot...
# 52  Use of Proceeds  \nEligibility Criteria  \nPro...
# 53   Frequency:  \n ☐ Annual  ☐ Semi -annual  \n ☒...
# 54  • The eligible categories for the use of proce...
# 55  Tracking of proceeds:  \n☒ Green Bond proceeds...
# 56   \nSection 3. Detailed review  \nReviewers are...
# 57  Frequency:  \n☒ Annual  ☐ Semi -annual  \n☐ Ot...
#
#                                             Passage 2  \
# 0   Conclusion   \nBPPEH  has developed the Blacks...
# 1   15 SPECIFY OTHER EXTERNAL REVIEWS AVAILABLE, I...
# 2   1. USE OF PROCEEDS  \nOverall comment on secti...
# 3    \n 18 ☒ Disclosure of portfolio balance of \n...
# 4   Section 3. Detailed review  \nReviewers are en...
# 5   12 ☐ Other (please specify):   \nImpact report...
# 6   2 Introduction  \nCTP Group (“CTP”, or “the Co...
# 7   12 SPECIFY OTHER EXTERNAL REVIEWS AVAILABLE, I...
# 8   10  \nThe eligible categories for the use of p...
# 9   13 SPECIFY OTHER EXTERNAL REVIEWS AVAILABLE, I...
# 10   \nUse of proceeds reporting:  \n☐ Project -by...
# 11   \nUse of proceeds reporting:  \n☐ Project -by...
# 12  Use of proceeds reporting:  \n☐ Project -by-pr...
# 13  Tracking of proceeds:  \n☒ Green  Bond proceed...
# 14  11 The eligible categories for the use of proc...
# 15  4. REPORTING  \nOverall comment on section (if...
# 16  As a state -owned entity, Specialfa stigheter ...
# 17  Tracking of proceeds:  \n☒ Green Bond proceeds...
# 18  Evaluation Summary  \nSustainalytics is of the...
# 19  12 Information on Responsibilities  and Accoun...
# 20  Vesteda  has developed the Vesteda Green Finan...
# 21  Use of proceeds reporting:  \n☐ Project -by-pr...
# 22  8 1. USE OF PROCEEDS  \nOverall comment on sec...
# 23  11 SPECIFY OTHER EXTERNAL REVIEWS AVAILABLE, I...
# 24  10   \nThe eligible categories for the use of ...
# 25  12  Use of proceeds reporting : \n☐ Project -b...
# 26  Xior  has developed the Xior Student Housing N...
# 27  Frequency:  \n☒ Annual  ☐ Semi -annual  \n☐ Ot...
# 28   \n4. REPORTING  \nOverall comment on section ...
# 29   \n4. REPORTING  \nOverall comment on section ...
# 30  The use of proceeds categories specified in th...
# 31  Use of proceeds reporting:  \n☐ Project -by-pr...
# 32  Conclusion  \nE.ON has developed a  Green Bond...
# 33  39 ☐ Linkage to individual bond(s)  ☐ Other (p...
# 34  Section 3. Detailed review  \nReviewer s are e...
# 35   \n4. REPORTING  \nOverall comment on section ...
# 36   \nSection 3: Impact of Use of Proceeds  \nThe...
# 37  Tracking of proceeds:  \n☒ Green Bond proceeds...
# 38  8 Section 3. Detailed review  \nReviewers are ...
# 39  Use of proceeds reporting:  \n☐ Project -by-pr...
# 40  Proceeds of the bond s will be used for projec...
# 41  Tracking of proceeds:  \n☒ Green Bond  proceed...
# 42   \nEvaluation Summary  \nSustainalytics is of ...
# 43  14 Information reported:  \n☒ Allocated amount...
# 44  3.1 Use of Proceeds  \nRepower  will use the n...
# 45   \nUse of proceeds categories as per GBP:  \n☒...
# 46  8  \nSection 3. Detailed review  \nReview ers ...
# 47  9 ☒ Defined and transparent criteria for proje...
# 48  6 Renewable Energy  7. Affordable & Clean Ener...
# 49  Evaluation and selection  \n☒ Credentials on t...
# 50  Water Wheels Green Securities has developed th...
# 51  Information on Responsibilities and Accountabi...
# 52  3. MANAGEMENT OF PROCEEDS  \nOverall comment o...
# 53  Use of proceeds reporting:  \n☒ Project -by-pr...
# 54  The net proceeds of each green bond will be us...
# 55  Use of proceeds categories as per GBP:  \n☐ Re...
# 56  3 Sustainalytics’ Opinion  \nSection 1: Sustai...
# 57  Use of proceeds reporting:  \n☐ Project -by-pr...
#
#                                             Passage 3  \
# 0   Evaluation Summary  \nSustainalytics is of the...
# 1   14 ☐ Linkage to individual bond(s)  ☐ Other (p...
# 2   Reporting  \n Yes  Castellum will publish a ye...
# 3    \n 2 EXECUTIVE SUMMARY   \nCastellum, an indu...
# 4   3 No information provided by Sustainalytics un...
# 5   10 ☐ Pollution prevention and control  ☐ Envir...
# 6   9 The eligible categories  for the use of proc...
# 7   4. REPORTING  \nOverall comment on section (if...
# 8   Evaluation Summary  \nSustainalytics is of the...
# 9   Deutsche Wohnen  intends to report on the allo...
# 10   \nUse of proceeds categories as per GBP:  \n☐...
# 11   \nUse of proceeds categories as per GBP:  \n☐...
# 12  Sustainalytics is of the opinion that projects...
# 13    15 \nUse of proceeds categories as per GBP: ...
# 14  Evaluation Summary  \nSustainalytics is of the...
# 15  Use of proceeds categories as per GBP:  \n☒ Re...
# 16  12 \n Section 3.  Detailed review  \n1. USE OF...
# 17  Use of proceeds categories as per GBP:  \n☒ Re...
# 18  8 Conclusion   \nTritax Euro Box has developed...
# 19  SPECIFY OTHER EXTERNAL REVIEWS AVAILABLE, IF A...
# 20  3 Sustainalytics’ Opinion  \nSection 1: Sustai...
# 21  Tracking of proceeds:  \n☒ Green Bond proceeds...
# 22  2 Introduction  \nVía Célere  SL (or the “Comp...
# 23  4. REPORTING  \nOverall comment on section (if...
# 24  2  Introduction  \nVonovia  (“Vonovia ” or the...
# 25   \nUse of proceeds categories as per GBP:  \n☒...
# 26  Evaluation Summary  \nSustainalytics is of the...
# 27  Use of proceeds reporting:  \n☐ Project -by-pr...
# 28  3 Sustainalytics’ Opinion  \nSection 1: Sustai...
# 29  Tracking of proceeds:  \n☒ Green Bond proceeds...
# 30   \nUse of proceeds categories as per GBP:  \n☒...
# 31   \nTracking of proceeds:  \n☒ Green Bond proce...
# 32   \nUse of proceeds reporting:  \n☐ Project -by...
# 33  38 Information on Responsibilities and Account...
# 34  8 ESB has developed the ESB Green Bond Framewo...
# 35  Tracking of proceeds:  \n☒ Green Bond proceeds...
# 36  The importance of clean t ransportation projec...
# 37   \nUse of proceeds categories as per GBP:  \n☒...
# 38  Midsummer h as developed the  Midsummer Green ...
# 39   \nTracking of proceeds:  \n☒ Green Bon d proc...
# 40  Landsvirkjun has developed a  Green Bond Frame...
# 41  Landsvirkjun, Iceland’s largest electricity co...
# 42  12 The eligible categories  for the use of pro...
# 43  4. REPORTING  \nOverall comment on section (if...
# 44  Given this context, Sustainalytics considers t...
# 45  The Opinion was drawn up with the aim to expla...
# 46  4 Sustainalytics’ Opinion  \nSection 1: Sustai...
# 47  10 Use of proceeds reporting:  \n☐ Project -by...
# 48  2 Introduction  \nSynthesis Analytics  (the “C...
# 49  Use of proceeds reporting:  \n☐ Project -by-pr...
# 50  Evaluation Summary  \nSustainalytics is of the...
# 51   \nUse of proceeds reporting:  \n☒ Project -by...
# 52   \nUse of proceeds categories as per GBP:  \n☐...
# 53   \nTracking of proceeds:  \n☒ Green Bond proce...
# 54  Ferrovie intends to use the proceeds for inves...
# 55  - Synergies between operators and technologies...
# 56   \nConclusion  \nVW has developed the Volkswag...
# 57  Tracking of proceeds:  \n☒ Green Bond proceeds...
#
#                                             Passage 4  \
# 0   5 • Project Evaluation and Selection:  \n- BPP...
# 1    \nUse of proceeds categories as per GBP:  \n☒...
# 2    \n 5 applicable criteria or to repay a Green ...
# 3   1. INTRODUCTION  \nCastellum intends to issue ...
# 4   Use of proceeds categories as per GBP:  \n☐ Re...
# 5   9 Review provider’s name:  Sustainalytics  \nC...
# 6   Use of proceeds categories as per GBP:  \n☒ Re...
# 7   Use of proceeds categories as per GBP:  \n☒ Re...
# 8    \nUse of proceeds categories as per GBP:  \n☒...
# 9    \nUse of proceeds categories as per GBP:  \n☒...
# 10  The eligible categor ies  for the use of proce...
# 11   \nTracking of proceeds:  \n☒ Green Bond proce...
# 12    3 \nIcade has engaged Sustainalytics to prov...
# 13  Well positioned to mitigate common Environment...
# 14  Use of proceeds categories as per GBP:  \n☒ Re...
# 15  12 Information on Responsibilities  and Accoun...
# 16  Use of proceeds categories as per GBP:  \n☒ Re...
# 17  14 \n ☐ Other (please specify) : \nAdditional ...
# 18  3 Sustainalytics ' Second -Party Opinion, whil...
# 19  Use of proceeds categories as per GBP:  \n☒ Re...
# 20  Use of proceeds categories as per GBP:  \n☐ Re...
# 21  Use of proceeds categories as per GBP:  \n☐ Re...
# 22  Evaluation Summary  \nSustainalytics is of the...
# 23  Use of proceeds categories as per GBP:  \n☐ Re...
# 24  Evaluation Summary  \nSustainalytics is of the...
# 25  Tracking of proceeds:  \n☒ Green Bond proceeds...
# 26  Section 3. Detailed review  \nReviewers are en...
# 27  Information on Responsibilities and Accountabi...
# 28  Use of proceeds categories as per GBP:  \n☒ Re...
# 29  Use of proceeds categories as per GBP:  \n☒ Re...
# 30  E.ON  has developed the E.ON Green Bond Framew...
# 31   \nUse of proceeds categories as per GBP:  \n☒...
# 32   \nUse of proceeds categories as per GBP:  \n☒...
# 33   \nUse of proceeds categories as per GBP:  \n☒...
# 34  ESB h as developed the  ESB Green Bond Framewo...
# 35  Use of proceeds categories as per GBP:  \n☒ Re...
# 36   \nConclusion  \ninnogy , a European energy co...
# 37  Section 1: Sustainalytics’ Opinion on the inno...
# 38  Use of Proceeds \nCategory  SDG  SDG target  \...
# 39   \nUse of proceeds categories as per  GBP:  \n...
# 40   \nUse of proceeds categories as per GBP:  \n☒...
# 41  Landsvirkjun ( or “the National Power Company ...
# 42  3 measurement and reporting of the impact achi...
# 43   \nUse of proceeds categories as per GBP:  \n☐...
# 44  Sustainalytics considers that the use of proce...
# 45  3.1 Use of Proceeds  \nRepower  will use the n...
# 46  2 Introduction  \nIn 2020, RWE  (“RWE ”, or th...
# 47  Use of proceeds categories as per GBP:  \n☒ Re...
# 48  Use of proceeds categories as per GBP:  \n☒ Re...
# 49  11 Tracking of proceeds:  \n☒ Green Bond proce...
# 50   \nUse of proceeds reporting:  \n☒ Project -by...
# 51  Use of proceeds categories as per GBP:  \n☒ Re...
# 52  Use of proceeds reporting:  \n☒ Project -by-pr...
# 53   \nUse of proceeds categories as per GBP:  \n☐...
# 54  Use of proceeds categories as per GBP:  \n☐ Re...
# 55  • The eligible categories for the use of proce...
# 56  VW has developed the Volkswagen Green Finance ...
# 57  Use of proceeds categories as per GBP:  \n☐ Re...
#
#                                             Passage 5  \
# 0   The Company, under the supervision of the Gree...
# 1   Tracking of proceeds:  \n☒ Green Bond proceeds...
# 2   Although Castellum does not commit to a ratio ...
# 3   2.3.1  Use of Proceeds  \nThe proceeds of the ...
# 4   2 Introduction  \nCibus Nordic Real Estate AB ...
# 5   4. REPORTING  \nOverall comment on section (if...
# 6   Evaluation Summary  \nSustainalytics is of the...
# 7   10 ☐ Other (please specify):    \n3. MANAGEMEN...
# 8   3 Sustainalytics’ Second -Party Opinion, while...
# 9   Tracking of procee ds:  \n☒ Green bond proceed...
# 10  2 Introduction  \nGlobalworth Real Estate Inve...
# 11  11 Evaluation and selection  \n☒ Credentials o...
# 12   \nConclusion  \nIcade, one of the leading com...
# 13    7 \nCO 2 emissions. In addit ion, the real e...
# 14  3 Any update of t he present Second -Party Opi...
# 15  2 Introduction  \nJohnson Controls Internation...
# 16  Use of proceeds reporting:  \n☒ Project -by-pr...
# 17  Contribution of the proceeds of the green bond...
# 18  13 Use of proceeds reporting : \n☐ Project -by...
# 19   \nTracking of proceeds:  \n☒ Green Bond proce...
# 20  Use of proceeds reporting:  \n☐ Project -by-pr...
# 21  Evaluation and selection  \n☒ Credentials on t...
# 22  Use of proceeds categories as per GBP:  \n☐ Re...
# 23  9 Information on Responsibilities  and Account...
# 24   \nUse of proceeds categories as per GBP:  \n☒...
# 25  14  Disclaimer  \nCopyright ©202 1 Sustainalyt...
# 26  3 Sustainalytics’ Opinion  \nSection 1: Sustai...
# 27  Tracking of proceeds:  \n☒ Green Bond proceeds...
# 28  Baseload Capital has developed the Baseload Ca...
# 29  10 ☐ Allocation to individual disbursements  ☐...
# 30  Use of proceeds reporting:  \n☐ Project -by-pr...
# 31  Additional disclosure:  \n☐ Allocations to fut...
# 32  Alignment with the Green Bond Principles 2018 ...
# 33   \nTracking of proceeds:  \n☒ Green Bond proce...
# 34  Based on ESB’  policies , programmes  and proc...
# 35  13 ☒ Allocation to individual disbursements  ☐...
# 36  Furthermore , the European Commission consider...
# 37  The importance of clean t ransportation projec...
# 38   \nUse of proceeds categories as per  GBP:  \n...
# 39  9 ☒ Defined and transparent criteria for proje...
# 40  Use of proceeds reporting:  \n☐ Project -by-pr...
# 41   \nUse of proceeds categories as per GBP:  \n☒...
# 42   \nUse of proceeds categories as per GBP:  \n☐...
# 43  13 Information on Responsibilities  and Accoun...
# 44   \nUse of proceeds categories as per GBP:  \n☒...
# 45   \n2. PREFACE  \nRepower plans to issue a Gre ...
# 46  Evaluation Summary  \nSustainalytics is of the...
# 47  Tracking of proceeds:  \n☒ Green Bond proceeds...
# 48  ROLE(S) OF REVIEW PROVIDER  \n☒ Consultancy (i...
# 49  Use of proceeds categories as per GBP:  \n☒ Re...
# 50  Use of proceeds categories as per GBP:  \n☒ Re...
# 51  Tracking of proceeds:  \n☒ Green Bond proceeds...
# 52   12 \nSection 3.  Detailed review  \nReviewers...
# 53  Section 2.  Review overview  \nSCOPE OF REVIEW...
# 54  Having reviewed Ferrovie ’s Green Bond Framewo...
# 55   \n 17 \nAll rights reserved. No part of this ...
# 56  Section 3: Impact of Use of Proceeds  \nThe us...
# 57  11 ☒ Disclosure of portfolio balance of \nunal...
#
#                                             Passage 6  \
# 0   Use of proceeds reporting : \n☐ Project -by-pr...
# 1   Evaluation and selection  \n☒ Credentials on t...
# 2   2.3.2  Process for Project Evaluation and Sele...
# 3   2.3 Castellum’s Green Bond  \nCastellum intend...
# 4   Evaluation Summary  \nSustainalytics is of the...
# 5   2. PROCESS FOR PROJECT EVALUATION AND SELECTIO...
# 6   4. REPORTING  \nOverall comment on section (if...
# 7   13 Disclaimer  \nCopyright ©2020 Sustainalytic...
# 8   2 Introduction  \nDeutsche Wohnen  SE Group  (...
# 9   Evaluation and selection  \n☒ Credentials on t...
# 10  4 Sustainalytics’ Opinion  \nSection 1: Sustai...
# 11  Section 2 . Review overview  \nSCOPE OF REVIEW...
# 12  However, Sustainalytics notes that t he majori...
# 13   \nConclusion  \nIcade, one of the leading com...
# 14  According to the International Energy Agency (...
# 15  2. PROCESS FOR PROJECT EVALUATION AND SELECTIO...
# 16  Overall, Sustainalytics is of the opinion that...
# 17  As a state -owned entity, Specialfa stigheter ...
# 18  Use of proceeds categories as per GBP:  \n☒ Re...
# 19   \nEvaluation and selection  \n☒ Credentials o...
# 20  As part of this engagement, Sustainalytics hel...
# 21  Section 2 . Review overview  \nSCOPE OF REVIEW...
# 22  4. REPORTING  \nOverall comment on section (if...
# 23  7 Append ix \nAppend ix 1: Green B ond / Green...
# 24  12  Use of proceeds reporting : \n☐ Project -b...
# 25  Evaluation and select ion  \n☒ Credentials on ...
# 26  Use of proceeds reporting:  \n☐ Project -by-pr...
# 27  Use of proceeds categories as per GBP:  \n☒ Re...
# 28  Section 3: Impact of Use of Proceeds  \nBoth u...
# 29  Evaluation and selection  \n☒ Credentials on t...
# 30  Section 3: Impact of Use of Proceeds  \nAll th...
# 31  11 ☒ Credentials on the issuer’s environmental...
# 32  Sustaina lytics has assessed  E.ON ’s Green Bo...
# 33   \nEvaluation and selection  \n☒ Credentials o...
# 34  Well positioned to address common environmenta...
# 35  Evaluation and selection  \n☒ Credentials on t...
# 36   \n 6 \nContributing to a sustainable energy t...
# 37  The company will publish an annual report disc...
# 38  Use of proceeds reporting:  \n☐ Project -by-pr...
# 39  Section 2 . Review overview  \nSCOPE OF REVIEW...
# 40  Contributing to  Iceland’s  100% renewable ene...
# 41  Contributing to  Iceland’s  100% renewable ene...
# 42  4. REPORTING  \nOverall comment on section (if...
# 43  2. PROCESS FOR PROJECT EVALUATION AND SELECTIO...
# 44  © Sustainalytics 2016  \n  9 \nImpact of use o...
# 45  Given this context, Sustainalytics considers t...
# 46  10 Use of proceeds reporting:  \n☐ Project -by...
# 47  Section 2 . Review overview  \nSCOPE OF REVIEW...
# 48  Use of proceeds reporting:  \n☐ Project -by-pr...
# 49  15 Disclaimer  \nCopyright ©2020 Sustainalytic...
# 50  Well positioned  to address common environment...
# 51  Additional disclosure:  \n☐ Allocations to fut...
# 52  Section 2.  Review overview  \nSCOPE OF REVIEW...
# 53  Use of Proceeds  \nEligibility Criteria  \nPro...
# 54  While the energy efficiency improvements  decl...
# 55  Well positioned to address common e nvironment...
# 56  Use of proceeds categories as per GBP:  \n☐ Re...
# 57   \nEvaluation and selection  \n☒ Credentials o...
#
#                                             Passage 7  \
# 0    \nUse of proceeds categories as per GBP:  \n☒...
# 1   16 Disclaimer  \nCopyright ©202 1 Sustainalyti...
# 2   2.3 Castellum’s Green Bond  \nCastellum intend...
# 3    \n 8 Management \nof Proceeds  \n Yes  The ne...
# 4   13 overarching objectives, strategy, policy an...
# 5   Use of proceeds categories as per GBP:  \n☐ Re...
# 6   3 No infor mation provided by Sustainalytics u...
# 7   2. PROCESS FOR PROJECT EVALUATION AND SELECTIO...
# 8   Net proceeds will be managed by Deutsche Wohne...
# 9   14 Disclaimer  \nCopyright ©202 1 Sustainalyti...
# 10  10  \nSection 3. Detailed review  \nReviewers ...
# 11  2 Introduction  \nGlobalworth Real Estate Inve...
# 12  • Strong commitment to allocation and imp act ...
# 13  In France, the real estate sector accounts for...
# 14  2 Introduction  \nJohnson Controls Internation...
# 15  Conclusion   \nJCI has developed the Johnson C...
# 16  3. MANAGEMENT OF PROCEEDS  \nOverall comment o...
# 17  Specialfastigheter  has engaged Sustainalytics...
# 18  4. REPORTING  \nOverall comment on section (if...
# 19  2 Introduction  \nTritax EuroBox plc  ("Tritax...
# 20  Second -Party Opinion  \nVesteda  Green Financ...
# 21  Additional disclosure:  \n☐ Allocations to fut...
# 22  9 Information on Responsibilities  and Account...
# 23  2. PROCESS FOR PROJECT EVALUA TION AND SELECTI...
# 24  3  In additio n, the Second -Party Opinion opi...
# 25  2  Introduction  \nVonovia  (“Vonovia ” or the...
# 26  Well positioned to address common environmenta...
# 27  10 ☒ Defined and transparent criteria for proj...
# 28  As part of this engagement, Sustainalytics hel...
# 29  Baseload Capital has described a process wher ...
# 30  As part of this engagement, Sustainalytics hel...
# 31  14 Disclaimer  \n© Sustainalytics 2019 . All r...
# 32  Section 3. Detailed review  \nReviewe rs are e...
# 33  3 (3) that any provided material information h...
# 34  Use of proceeds categories as per GBP:  \n☒ Re...
# 35  16 Disclaimer  \n© Sustainalytics 201 9. All r...
# 36  Section 1: Sustainalytics’ Opinion on the inno...
# 37  Disclaimer  \nAll rights  reserved. No part of...
# 38  3 Sustainalytics’ Opinion  \nSection 1: Sustai...
# 39  Additional disclosure:  \n☐ Allocations to fut...
# 40  Landsvirkjun, Iceland’s largest electricity co...
# 41  Overall, Sustainalytics is confident that the ...
# 42  2 Introduction  \nNeutral Fuels  LLC  (“Neutra...
# 43  Tracking of proceeds:  \n☒ Green Bond proceeds...
# 44  © Sustainalytics 2016  \n  8 \nSustainalytics’...
# 45   \nConclusion  \nRepower’s Green SSD  framewor...
# 46  Use of proceeds categories as per GBP:  \n☒ Re...
# 47  12 Disclaimer  \nCopyright ©2020 Sustainalytic...
# 48  Evaluation Summary  \nSustainalytics is of the...
# 49  2 Introduction  \nSynthesis Analytics  (the “C...
# 50  3 Sustainalytics’ Opinion  \nSection 1: Sustai...
# 51  Well positioned  to address common environment...
# 52  Project Evaluation and Selection  Process  \nA...
# 53  Disclaimer  \nAll rights reserved. No part of ...
# 54  As part of this engagement, Sustainalytics hel...
# 55  As part of this engagement, Sustainalytics hel...
# 56  Use of proceeds reporting:  \n☐ Project -by-pr...
# 57  3 Sustainalytics’ Opinion  \nSection 1: Sustai...
#
#                                             Passage 8  \
# 0   BPPEH  engaged Sustainalytics to review the  F...
# 1   6 BPPEH has provided to Sustainalytics a list ...
# 2   Castellum will publish a yearly report describ...
# 3    \n4. REPORTING  \nOverall comment on section ...
# 4   4. REPORTING  \nOverall comment on section (if...
# 5   2 Introduction  \nCibus Nordic Real Estate AB ...
# 6   Section 3. Detailed review  \nReviewe rs are e...
# 7   2 Introduction  \nCTP Group (“CTP”, or “the Co...
# 8   Deutsche Wohnen  intends to report on the allo...
# 9   2 Introduction  \nDeutsche Wohnen  SE Group  (...
# 10  Evaluation Summary  \nSustainalytics is of the...
# 11   \nConclusion   \nGlobalworth has developed th...
# 12    16 \n3. MANAGEMENT OF PROCEEDS  \nOverall co...
# 13  Sustainalytics considers that Icade ’s Green B...
# 14  Section 3. Detailed review  \nReviewe rs are e...
# 15  3 Any update of t he present Second -Party Opi...
# 16  Specialfastigheter  has engaged Sustainalytics...
# 17  Through consultation, Sustainalytics understan...
# 18  Section 3. Detailed review  \nReviewers are en...
# 19  15 Disclaimer  \nCopyright ©202 1 Sustainalyti...
# 20  Contribution of framework to Vesteda’s  sustai...
# 21  3 Sustainalytics’ Opinion  \nSection 1: Sustai...
# 22  3 No information provided by Sustainalytics un...
# 23  5 outcomes . Some key environmental and social...
# 24  Section 3. Detailed review  \nReviewe rs are e...
# 25  5  energy,  and promoting biodiversity at its ...
# 26  The Xior Student Housing N.V. Green Finance Fr...
# 27  Additional disclosure:  \n☐ Allocations to fut...
# 28  12 sustainable features of underlying assets m...
# 29  13 Disclaimer  \n© Sustainalytics 2018. All ri...
# 30  Imp ortance of clean transportation in mitigat...
# 31   \nConclusion  \nE.ON  SE has developed the E....
# 32  10 procurement of goods and services.32 E.ON’s...
# 33  2 Introduction  \nE.ON SE (“E.ON”, the “Issuer...
# 34  ESB’s process for project evaluation and selec...
# 35   \nABOUT ROLE(S) OF INDEPENDENT REVIEW PROVIDE...
# 36   \nUse of proceeds categories as per GBP:  \n☒...
# 37  innogy  has engaged S ustainalytics to provide...
# 38  As part of this engagement, Sustainalytics hel...
# 39  12 © Sustainalytics 2018. All rights reserved....
# 40  3. MANAGEMENT OF PROCEEDS  \nOverall comment o...
# 41  Proceeds of the bond s will be used for projec...
# 42  Section 3. Detailed review  \nReviewe rs are e...
# 43  5 •  \n• Technology -enabled operational effic...
# 44  Repower will use the net proceeds of the Green...
# 45   \n3.3 Management of Proce eds  \nProceeds fro...
# 46   \nABOUT ROLE(S) OF INDEPENDENT REVIEW PROVIDE...
# 47  5 Section 2: Sustainability Performance of RWE...
# 48  9  \nSection 2 . Review overview  \nSCOPE OF R...
# 49  9  \nSection 2 . Review overview  \nSCOPE OF R...
# 50   \nABOUT ROLE(S) OF INDEPENDENT REVIEW PROVIDE...
# 51  9 Evaluation and selection  \n☒ Credentials on...
# 52  Disclaimer  \nAll rights reserved. No part of ...
# 53  In addition to the general importance of rail ...
# 54   \n 15 \nRegarding impact reporting, Ferrovie ...
# 55  Given Ferrovie’s use of envi ronmental impact ...
# 56  Evaluation Summary  \nSustainalytics is of the...
# 57  As part of this engagement, Sustainalytics hel...
#
#                                             Passage 9  \
# 0   7 Section 3: Impact of Use of Proceeds  \nAll ...
# 1   Conclusion   \nBPPEH  has developed the Blacks...
# 2   2.2.3  Management of Proceeds   \nGreen Bond n...
# 3   Reporting  \n Yes  Castellum will publish a ye...
# 4   5 Section 3: Impact of Use of Proceeds  \nThe ...
# 5   11  \n3. MANAGEMENT  OF PROCEEDS  \nOverall co...
# 6   12 SPECIFY OTHER EXTERNAL REVIEWS AVAILABLE, I...
# 7   18 Ministry of Energy, “ Integrated National E...
# 8   Section 3. Detailed review  \nReviewers are en...
# 9   3 Sustainalytics’ Second -Party Opinion, while...
# 10  ABOUT ROLE(S) OF INDEPENDENT REVIEW PROVIDERS ...
# 11  Evaluation Summary  \nSustainalytics is of the...
# 12  Contribu tion of the proceeds of the green bon...
# 13  6 Similarly to a positive energy building whic...
# 14  4. REPORTING  \nOverall comment on section (if...
# 15  6 projects could also lead to negative environ...
# 16  Disclaimer  \nAll rights reserved. No part of ...
# 17  Specialfastigheter has developed a Green Bond ...
# 18  2 Introduction  \nTritax EuroBox plc  ("Tritax...
# 19  4 been disclosed by the Group  to represent a ...
# 20  3. MANAGEMENT OF PROCEEDS  \nOverall comment o...
# 21  13 Disclaimer  \n© Sustainalytics 201 9. All r...
# 22  11 SPECIFY OTHER EXTERNAL REVIEWS AVAILABLE, I...
# 23  12 Disc laimer  \nCopyright ©202 1 Sustainalyt...
# 24  4  increase the utilization of renewable energ...
# 25  4  increase the utilization of renewable energ...
# 26  Use of proceeds categories as per GBP:  \n☒ Re...
# 27  Xior  has developed the Xior Student Housing N...
# 28  Second -Party Opinion  \nBaseload Capital  Gre...
# 29  5 Japan has set targets to reduce GHG emission...
# 30  Section 3. Detailed review  \nReviewers are en...
# 31  4 methodology, and considers it to directly li...
# 32   \n13 \n Appendi ces  \nAppendix 1: Approach t...
# 33  6 • Management of Proceeds:  \n-  E.ON  will m...
# 34  As part of this engagement, Sustainalytics hel...
# 35  ESB h as developed the  ESB Green Bond Framewo...
# 36  2. PROCESS FOR PROJECT EVALUATION AND SELECTIO...
# 37   \n 13 \n4. REPORTING  \nOverall comment on se...
# 38  Review provider(s):  Date of publication:  \n ...
# 39  Within Midsummer’s  CSR Policy and Code of Con...
# 40  Landsvirkjun  engaged Sustainalytics to provid...
# 41  Landsvirkjun has developed a  Green Bond Frame...
# 42  8 Alignment with/contribution to SDGs  \nThe S...
# 43  16 Disclaimer  \nCopyright ©202 1 Sustainalyti...
# 44  © Sustainalytics 2016  \n  2 \nTABLE OF CONTEN...
# 45  Sustainalytics considers that the use of proce...
# 46  Section 2 . Review overview  \nSCOPE OF REVIEW...
# 47   \nABOUT ROLE(S) OF INDEPENDENT REVIEW PROVIDE...
# 48   \nABOUT ROLE(S) OF INDEPENDENT REVIEW PROVIDE...
# 49           4 Capturing the energy of waste -heat.
# 50  As part of this engagement, Sustainalytics hel...
# 51  13 Disclaimer  \n© Sustainalytics 20 20. All r...
# 52  Conclusion   \nClean transportation is recogni...
# 53  Reporting  \nAllocation Reporting  \nAlpha Tra...
# 54  Alignment with/contribution to SDGs  \nThe Sus...
# 55   \n 11 \nWith regard  to the  traction chain :...
# 56  VW  intends to use its Green Bo nds’ and Loans...
# 57  Evaluation Summary  \nSustainalytics is of the...
#
#                                            Passage 10  \
# 0   3 This docum ent contains Sustainalytics’ opin...
# 1   6 implementation of its group -wide  sustainab...
# 2    \n4. REPORTING  \nOverall comment on section ...
# 3   Where Castellum is responsible for project ope...
# 4   9 Review provider’s name:  Sustainalytics  \nC...
# 5   14 Disclaimer  \nCopyright ©2020 Sustainalytic...
# 6   5 habitats.” Concerning land use the Directive...
# 7   4 environmental impact metrics, see Appendix 2...
# 8   4 - Within the Renewable Energy category, Deut...
# 9   5 As part of the Company’s  focus on its envir...
# 10  Section 2 . Review overview  \nSCOPE OF REVIEW...
# 11  10 GWI, “Globalworth Real Estate Investments L...
# 12  Tracking of proceeds:  \n☒ Green  Bond proceed...
# 13  However, Sustainalytics notes that t he majori...
# 14  14 Review provider(s):  Date of publication:  ...
# 15  4 Potential ).6  Furthermore,  in relation to ...
# 16  Through consultation, Sustainalytics understan...
# 17  Disclaimer  \nAll rights reserved. No part of ...
# 18  SPECIFY OTHER EXTERNAL REVIEWS AVAILABLE, IF A...
# 19  8 Conclusion   \nTritax Euro Box has developed...
# 20  4 • Reporting:  \n- Vesteda will report on the...
# 21   \nConclusion  \nVesteda’s Green Finance Frame...
# 22  7 Append ix \nAppend ix 1: Green B ond / Green...
# 23  2 Introduction  \nVía Célere  SL (or the “Comp...
# 24  6  • As part of its occupational health and sa...
# 25  6  • As part of its occupational health and sa...
# 26  Based on these policies, standards and assessm...
# 27  4 • Project Evaluation and Selection:  \n- Xio...
# 28   \nABOUT ROLE(S) OF INDEPENDENT REVIEW PROVIDE...
# 29  3 Sustainalytics’ Opinion  \nSection 1: Sustai...
# 30  Second -Party Opinion  \nE.ON  Green Bond   \n...
# 31  Second -Party Opinion  \nE.ON  Green Bond   \n...
# 32  2 Introduction  \nE.ON SE (“E.ON”, the “Issuer...
# 33  28 Table 1 3 \nFramework Activity assessed  En...
# 34   \n4. REPORTING  \nOverall comment on section ...
# 35  Second -Party Opinion  \nESB G reen Bond   \n ...
# 36  Use of proceeds reporting:  \n☒ Project -by-pr...
# 37  innogy  has developed a Green Bond F ramework1...
# 38  Section 2 . Review overview  \nSCOPE OF REVIEW...
# 39  3 Sustainalytics’ Opinion  \nSection 1: Sustai...
# 40  Overall, Sustainalytics is confident that the ...
# 41  Landsvirkjun  engaged Sustainalytics to provid...
# 42  15 ☐ Verification / Audit  ☐ Rating  \n☐ Other...
# 43  2 Introduction  \nNeutral Fuels  LLC  (“Neutra...
# 44  For this issuance, Repower will use the net pr...
# 45  © Sustainalytics 2016  \n  8 \nSustainalytics’...
# 46  9 ☒ Defined and transparent criteria for proje...
# 47  4 Sustainalytics’ Opinion  \nSection 1: Sustai...
# 48  5 • The Swedish Work Environment Authority (SW...
# 49  5 • The Swedish Work Environment Authority (SW...
# 50   \nConclusion  \nWater Wheel Green Securities ...
# 51  3 Sustainalytics’ Opinion  \nSection 1: Sustai...
# 52  In addition to compliance with ESG Policy, Alp...
# 53  Project Evaluation and Selection  Process  \nA...
# 54  The company’s management of the bond proceeds ...
# 55  Ferrovie intends to use the proceeds for inves...
# 56  As part of this engagement, Sustainalytics hel...
# 57  While electric mobility has a big potential to...
#
#                       labels
# 0        [1, 2, 3, 7, 9, 10]
# 1              [4, 8, 9, 10]
# 2               [2, 5, 6, 7]
# 3                     [3, 6]
# 4         [1, 2, 3, 5, 6, 9]
# 5                     [3, 8]
# 6     [1, 2, 3, 4, 5, 7, 10]
# 7              [1, 4, 8, 10]
# 8     [1, 2, 3, 4, 5, 6, 10]
# 9                     [8, 9]
# 10        [1, 3, 4, 5, 6, 8]
# 11              [3, 7, 8, 9]
# 12                    [1, 5]
# 13           [3, 4, 6, 7, 9]
# 14     [1, 2, 3, 4, 5, 6, 7]
# 15              [3, 5, 7, 8]
# 16           [1, 2, 3, 4, 6]
# 17                    [3, 9]
# 18        [1, 2, 3, 4, 6, 9]
# 19                 [4, 7, 9]
# 20           [1, 2, 3, 4, 7]
# 21                [4, 8, 10]
# 22           [1, 2, 3, 5, 8]
# 23                   [4, 10]
# 24           [1, 2, 3, 5, 9]
# 25                 [3, 7, 9]
# 26        [1, 2, 3, 4, 5, 9]
# 27                    [6, 9]
# 28           [1, 3, 4, 5, 9]
# 29                   [4, 10]
# 30             [1, 3, 4, 10]
# 31                [4, 8, 10]
# 32          [1, 2, 4, 5, 10]
# 33                    [4, 8]
# 34           [1, 2, 3, 4, 7]
# 35                [4, 9, 10]
# 36  [1, 2, 3, 4, 5, 6, 7, 8]
# 37             [3, 4, 5, 10]
# 38        [1, 2, 3, 4, 5, 7]
# 39                   [4, 10]
# 40           [1, 2, 3, 4, 7]
# 41              [3, 5, 8, 9]
# 42        [1, 2, 3, 4, 5, 7]
# 43                [4, 8, 10]
# 44    [1, 2, 3, 4, 5, 8, 10]
# 45           [2, 4, 6, 7, 9]
# 46           [2, 3, 4, 5, 7]
# 47                   [4, 10]
# 48           [1, 2, 3, 4, 7]
# 49                 [1, 5, 7]
# 50       [1, 2, 3, 5, 7, 10]
# 51                   [4, 10]
# 52                 [1, 2, 3]
# 53                    [4, 6]
# 54              [1, 2, 3, 4]
# 55                [2, 4, 10]
# 56        [1, 2, 3, 4, 8, 9]
# 57                 [4, 7, 9]

# %%
df_bert
# Out:
#                                               Company  \
# 1           Blackstone_External%20Review%20Report.pdf
# 3            Castellum_External%20Review%20Report.pdf
# 5                Cibus_External%20Review%20Report.pdf
# 7                  CTP_External%20Review%20Report.pdf
# 9    Deutsche%20Wohnen_External%20Review%20Report.pdf
# 11         Globalworth_External%20Review%20Report.pdf
# 13               ICADE_External%20Review%20Report.pdf
# 15             Johnson_External%20Review%20Report.pdf
# 17  Specialfastigheter-External%20Review%20Report.pdf
# 19      tritax-eurobox_External%20Review%20Report.pdf
# 21             Vesteda_External%20Review%20Report.pdf
# 23  V%C3%ADa%20C%C3%A9lere_External%20Review%20Rep...
# 25             Vonovia_External%20Review%20Report.pdf
# 27                Xior_External%20Review%20Report.pdf
# 29  Baseload%20Capital_External%20Review%20Report.pdf
# 31                E.ON_External%20Review%20Report.pdf
# 33         E.ON_External%20Review%20Report%202021.pdf
# 35                 ESB_External%20Review%20Report.pdf
# 37              innogy_External%20Review%20Report.pdf
# 39           Midsummer_External%20Review%20Report.pdf
# 41        Landsvirkjun-External%20Review%20Report.pdf
# 43     neutral%20fuels_External%20Review%20Report.pdf
# 45             Repower_External%20Review%20Report.pdf
# 47                 RWE_External%20Review%20Report.pdf
# 49  Synthesis%20Analytics_External%20Review%20Repo...
# 51       Water%20Wheel_External%20Review%20Report.pdf
# 53      Alpha%20Trains_External%20Review%20Report.pdf
# 55            Ferrovie_External%20Review%20Report.pdf
# 57   Volkswagen_External%20Review%20Report%202020.pdf
#
#                       Sector                                  Query Method  \
# 1      Corporate-Real Estate  what did the use of proceeds finance?   BERT
# 3      Corporate-Real Estate  what did the use of proceeds finance?   BERT
# 5      Corporate-Real Estate  what did the use of proceeds finance?   BERT
# 7      Corporate-Real Estate  what did the use of proceeds finance?   BERT
# 9      Corporate-Real Estate  what did the use of proceeds finance?   BERT
# 11     Corporate-Real Estate  what did the use of proceeds finance?   BERT
# 13     Corporate-Real Estate  what did the use of proceeds finance?   BERT
# 15     Corporate-Real Estate  what did the use of proceeds finance?   BERT
# 17     Corporate-Real Estate  what did the use of proceeds finance?   BERT
# 19     Corporate-Real Estate  what did the use of proceeds finance?   BERT
# 21     Corporate-Real Estate  what did the use of proceeds finance?   BERT
# 23     Corporate-Real Estate  what did the use of proceeds finance?   BERT
# 25     Corporate-Real Estate  what did the use of proceeds finance?   BERT
# 27     Corporate-Real Estate  what did the use of proceeds finance?   BERT
# 29          Corporate-Energy  what did the use of proceeds finance?   BERT
# 31          Corporate-Energy  what did the use of proceeds finance?   BERT
# 33          Corporate-Energy  what did the use of proceeds finance?   BERT
# 35          Corporate-Energy  what did the use of proceeds finance?   BERT
# 37          Corporate-Energy  what did the use of proceeds finance?   BERT
# 39          Corporate-Energy  what did the use of proceeds finance?   BERT
# 41          Corporate-Energy  what did the use of proceeds finance?   BERT
# 43          Corporate-Energy  what did the use of proceeds finance?   BERT
# 45          Corporate-Energy  what did the use of proceeds finance?   BERT
# 47          Corporate-Energy  what did the use of proceeds finance?   BERT
# 49          Corporate-Energy  what did the use of proceeds finance?   BERT
# 51          Corporate-Energy  what did the use of proceeds finance?   BERT
# 53  Corporate-Transportation  what did the use of proceeds finance?   BERT
# 55  Corporate-Transportation  what did the use of proceeds finance?   BERT
# 57  Corporate-Transportation  what did the use of proceeds finance?   BERT
#
#                                             Passage 1  \
# 1   Use of proceeds reporting : \n☐ Project -by-pr...
# 3   Tracking of proceeds:  \n☒ Green Bond proceeds...
# 5   Where appropriate, please specify name and dat...
# 7   11 Frequency:  \n☒ Annual  ☐ Semi -annual  \n☐...
# 9   12 ☐ Linkage to individual bond(s)  ☐ Other (p...
# 11  Frequency:  \n☒ Annual  ☐ Semi -annual  \n☐ Ot...
# 13  Use of proceeds reporting:  \n☐ Project -by-pr...
# 15  13 Information reported:  \n☒ Allocated amount...
# 17  Use of proceeds reporting:  \n☒ Project -by-pr...
# 19  13 Use of proceeds reporting : \n☐ Project -by...
# 21  Frequency:  \n☒ Annual  ☐ Semi -annual  \n☐ Ot...
# 23  10 Information reported:  \n☒ Allocated amou n...
# 25  13  SPECIFY OTHER EXTERNAL REVIEWS AVAILABLE, ...
# 27  Information reported:  \n☒ Allocated amounts  ...
# 29  Frequency:  \n☒ Annual  ☐ Semi -annual  \n☐ Ot...
# 31  Frequency:  \n☒ Annual  ☐ Semi -annual  \n☐ Ot...
# 33   \nUse of proceeds reporting:  \n☐ Project -by...
# 35  14  \nFrequency:  \n☒ Annual  ☐ Semi -annual  ...
# 37  Use of proceeds reporting:  \n☒ Project -by-pr...
# 39  Frequency:  \n☒ Annual  ☐ Semi -annual  \n☐ Ot...
# 41  Use of proceeds reporting:  \n☐ Project -by-pr...
# 43  15 ☐ Verification / Audit  ☐ Rating  \n☐ Other...
# 45  Tracking of proceeds:  \n☒ Green Bond proceeds...
# 47  Frequency:  \n☒ Annual  ☐ Semi -annual  \n☐ Ot...
# 49  ROLE(S) OF REVIEW PROVIDER  \n☒ Consultancy (i...
# 51  Frequency:  \n☒ Annual  ☐ Semi -annual  \n☐ Ot...
# 53   Frequency:  \n ☐ Annual  ☐ Semi -annual  \n ☒...
# 55  Tracking of proceeds:  \n☒ Green Bond proceeds...
# 57  Frequency:  \n☒ Annual  ☐ Semi -annual  \n☐ Ot...
#
#                                             Passage 2  \
# 1   15 SPECIFY OTHER EXTERNAL REVIEWS AVAILABLE, I...
# 3    \n 18 ☒ Disclosure of portfolio balance of \n...
# 5   12 ☐ Other (please specify):   \nImpact report...
# 7   12 SPECIFY OTHER EXTERNAL REVIEWS AVAILABLE, I...
# 9   13 SPECIFY OTHER EXTERNAL REVIEWS AVAILABLE, I...
# 11   \nUse of proceeds reporting:  \n☐ Project -by...
# 13  Tracking of proceeds:  \n☒ Green  Bond proceed...
# 15  4. REPORTING  \nOverall comment on section (if...
# 17  Tracking of proceeds:  \n☒ Green Bond proceeds...
# 19  12 Information on Responsibilities  and Accoun...
# 21  Use of proceeds reporting:  \n☐ Project -by-pr...
# 23  11 SPECIFY OTHER EXTERNAL REVIEWS AVAILABLE, I...
# 25  12  Use of proceeds reporting : \n☐ Project -b...
# 27  Frequency:  \n☒ Annual  ☐ Semi -annual  \n☐ Ot...
# 29   \n4. REPORTING  \nOverall comment on section ...
# 31  Use of proceeds reporting:  \n☐ Project -by-pr...
# 33  39 ☐ Linkage to individual bond(s)  ☐ Other (p...
# 35   \n4. REPORTING  \nOverall comment on section ...
# 37  Tracking of proceeds:  \n☒ Green Bond proceeds...
# 39  Use of proceeds reporting:  \n☐ Project -by-pr...
# 41  Tracking of proceeds:  \n☒ Green Bond  proceed...
# 43  14 Information reported:  \n☒ Allocated amount...
# 45   \nUse of proceeds categories as per GBP:  \n☒...
# 47  9 ☒ Defined and transparent criteria for proje...
# 49  Evaluation and selection  \n☒ Credentials on t...
# 51  Information on Responsibilities and Accountabi...
# 53  Use of proceeds reporting:  \n☒ Project -by-pr...
# 55  Use of proceeds categories as per GBP:  \n☐ Re...
# 57  Use of proceeds reporting:  \n☐ Project -by-pr...
#
#                                             Passage 3  \
# 1   14 ☐ Linkage to individual bond(s)  ☐ Other (p...
# 3    \n 2 EXECUTIVE SUMMARY   \nCastellum, an indu...
# 5   10 ☐ Pollution prevention and control  ☐ Envir...
# 7   4. REPORTING  \nOverall comment on section (if...
# 9   Deutsche Wohnen  intends to report on the allo...
# 11   \nUse of proceeds categories as per GBP:  \n☐...
# 13    15 \nUse of proceeds categories as per GBP: ...
# 15  Use of proceeds categories as per GBP:  \n☒ Re...
# 17  Use of proceeds categories as per GBP:  \n☒ Re...
# 19  SPECIFY OTHER EXTERNAL REVIEWS AVAILABLE, IF A...
# 21  Tracking of proceeds:  \n☒ Green Bond proceeds...
# 23  4. REPORTING  \nOverall comment on section (if...
# 25   \nUse of proceeds categories as per GBP:  \n☒...
# 27  Use of proceeds reporting:  \n☐ Project -by-pr...
# 29  Tracking of proceeds:  \n☒ Green Bond proceeds...
# 31   \nTracking of proceeds:  \n☒ Green Bond proce...
# 33  38 Information on Responsibilities and Account...
# 35  Tracking of proceeds:  \n☒ Green Bond proceeds...
# 37   \nUse of proceeds categories as per GBP:  \n☒...
# 39   \nTracking of proceeds:  \n☒ Green Bon d proc...
# 41  Landsvirkjun, Iceland’s largest electricity co...
# 43  4. REPORTING  \nOverall comment on section (if...
# 45  The Opinion was drawn up with the aim to expla...
# 47  10 Use of proceeds reporting:  \n☐ Project -by...
# 49  Use of proceeds reporting:  \n☐ Project -by-pr...
# 51   \nUse of proceeds reporting:  \n☒ Project -by...
# 53   \nTracking of proceeds:  \n☒ Green Bond proce...
# 55  - Synergies between operators and technologies...
# 57  Tracking of proceeds:  \n☒ Green Bond proceeds...
#
#                                             Passage 4  \
# 1    \nUse of proceeds categories as per GBP:  \n☒...
# 3   1. INTRODUCTION  \nCastellum intends to issue ...
# 5   9 Review provider’s name:  Sustainalytics  \nC...
# 7   Use of proceeds categories as per GBP:  \n☒ Re...
# 9    \nUse of proceeds categories as per GBP:  \n☒...
# 11   \nTracking of proceeds:  \n☒ Green Bond proce...
# 13  Well positioned to mitigate common Environment...
# 15  12 Information on Responsibilities  and Accoun...
# 17  14 \n ☐ Other (please specify) : \nAdditional ...
# 19  Use of proceeds categories as per GBP:  \n☒ Re...
# 21  Use of proceeds categories as per GBP:  \n☐ Re...
# 23  Use of proceeds categories as per GBP:  \n☐ Re...
# 25  Tracking of proceeds:  \n☒ Green Bond proceeds...
# 27  Information on Responsibilities and Accountabi...
# 29  Use of proceeds categories as per GBP:  \n☒ Re...
# 31   \nUse of proceeds categories as per GBP:  \n☒...
# 33   \nUse of proceeds categories as per GBP:  \n☒...
# 35  Use of proceeds categories as per GBP:  \n☒ Re...
# 37  Section 1: Sustainalytics’ Opinion on the inno...
# 39   \nUse of proceeds categories as per  GBP:  \n...
# 41  Landsvirkjun ( or “the National Power Company ...
# 43   \nUse of proceeds categories as per GBP:  \n☐...
# 45  3.1 Use of Proceeds  \nRepower  will use the n...
# 47  Use of proceeds categories as per GBP:  \n☒ Re...
# 49  11 Tracking of proceeds:  \n☒ Green Bond proce...
# 51  Use of proceeds categories as per GBP:  \n☒ Re...
# 53   \nUse of proceeds categories as per GBP:  \n☐...
# 55  • The eligible categories for the use of proce...
# 57  Use of proceeds categories as per GBP:  \n☐ Re...
#
#                                             Passage 5  \
# 1   Tracking of proceeds:  \n☒ Green Bond proceeds...
# 3   2.3.1  Use of Proceeds  \nThe proceeds of the ...
# 5   4. REPORTING  \nOverall comment on section (if...
# 7   10 ☐ Other (please specify):    \n3. MANAGEMEN...
# 9   Tracking of procee ds:  \n☒ Green bond proceed...
# 11  11 Evaluation and selection  \n☒ Credentials o...
# 13    7 \nCO 2 emissions. In addit ion, the real e...
# 15  2 Introduction  \nJohnson Controls Internation...
# 17  Contribution of the proceeds of the green bond...
# 19   \nTracking of proceeds:  \n☒ Green Bond proce...
# 21  Evaluation and selection  \n☒ Credentials on t...
# 23  9 Information on Responsibilities  and Account...
# 25  14  Disclaimer  \nCopyright ©202 1 Sustainalyt...
# 27  Tracking of proceeds:  \n☒ Green Bond proceeds...
# 29  10 ☐ Allocation to individual disbursements  ☐...
# 31  Additional disclosure:  \n☐ Allocations to fut...
# 33   \nTracking of proceeds:  \n☒ Green Bond proce...
# 35  13 ☒ Allocation to individual disbursements  ☐...
# 37  The importance of clean t ransportation projec...
# 39  9 ☒ Defined and transparent criteria for proje...
# 41   \nUse of proceeds categories as per GBP:  \n☒...
# 43  13 Information on Responsibilities  and Accoun...
# 45   \n2. PREFACE  \nRepower plans to issue a Gre ...
# 47  Tracking of proceeds:  \n☒ Green Bond proceeds...
# 49  Use of proceeds categories as per GBP:  \n☒ Re...
# 51  Tracking of proceeds:  \n☒ Green Bond proceeds...
# 53  Section 2.  Review overview  \nSCOPE OF REVIEW...
# 55   \n 17 \nAll rights reserved. No part of this ...
# 57  11 ☒ Disclosure of portfolio balance of \nunal...
#
#                                             Passage 6  \
# 1   Evaluation and selection  \n☒ Credentials on t...
# 3   2.3 Castellum’s Green Bond  \nCastellum intend...
# 5   2. PROCESS FOR PROJECT EVALUATION AND SELECTIO...
# 7   13 Disclaimer  \nCopyright ©2020 Sustainalytic...
# 9   Evaluation and selection  \n☒ Credentials on t...
# 11  Section 2 . Review overview  \nSCOPE OF REVIEW...
# 13   \nConclusion  \nIcade, one of the leading com...
# 15  2. PROCESS FOR PROJECT EVALUATION AND SELECTIO...
# 17  As a state -owned entity, Specialfa stigheter ...
# 19   \nEvaluation and selection  \n☒ Credentials o...
# 21  Section 2 . Review overview  \nSCOPE OF REVIEW...
# 23  7 Append ix \nAppend ix 1: Green B ond / Green...
# 25  Evaluation and select ion  \n☒ Credentials on ...
# 27  Use of proceeds categories as per GBP:  \n☒ Re...
# 29  Evaluation and selection  \n☒ Credentials on t...
# 31  11 ☒ Credentials on the issuer’s environmental...
# 33   \nEvaluation and selection  \n☒ Credentials o...
# 35  Evaluation and selection  \n☒ Credentials on t...
# 37  The company will publish an annual report disc...
# 39  Section 2 . Review overview  \nSCOPE OF REVIEW...
# 41  Contributing to  Iceland’s  100% renewable ene...
# 43  2. PROCESS FOR PROJECT EVALUATION AND SELECTIO...
# 45  Given this context, Sustainalytics considers t...
# 47  Section 2 . Review overview  \nSCOPE OF REVIEW...
# 49  15 Disclaimer  \nCopyright ©2020 Sustainalytic...
# 51  Additional disclosure:  \n☐ Allocations to fut...
# 53  Use of Proceeds  \nEligibility Criteria  \nPro...
# 55  Well positioned to address common e nvironment...
# 57   \nEvaluation and selection  \n☒ Credentials o...
#
#                                             Passage 7  \
# 1   16 Disclaimer  \nCopyright ©202 1 Sustainalyti...
# 3    \n 8 Management \nof Proceeds  \n Yes  The ne...
# 5   Use of proceeds categories as per GBP:  \n☐ Re...
# 7   2. PROCESS FOR PROJECT EVALUATION AND SELECTIO...
# 9   14 Disclaimer  \nCopyright ©202 1 Sustainalyti...
# 11  2 Introduction  \nGlobalworth Real Estate Inve...
# 13  In France, the real estate sector accounts for...
# 15  Conclusion   \nJCI has developed the Johnson C...
# 17  Specialfastigheter  has engaged Sustainalytics...
# 19  2 Introduction  \nTritax EuroBox plc  ("Tritax...
# 21  Additional disclosure:  \n☐ Allocations to fut...
# 23  2. PROCESS FOR PROJECT EVALUA TION AND SELECTI...
# 25  2  Introduction  \nVonovia  (“Vonovia ” or the...
# 27  10 ☒ Defined and transparent criteria for proj...
# 29  Baseload Capital has described a process wher ...
# 31  14 Disclaimer  \n© Sustainalytics 2019 . All r...
# 33  3 (3) that any provided material information h...
# 35  16 Disclaimer  \n© Sustainalytics 201 9. All r...
# 37  Disclaimer  \nAll rights  reserved. No part of...
# 39  Additional disclosure:  \n☐ Allocations to fut...
# 41  Overall, Sustainalytics is confident that the ...
# 43  Tracking of proceeds:  \n☒ Green Bond proceeds...
# 45   \nConclusion  \nRepower’s Green SSD  framewor...
# 47  12 Disclaimer  \nCopyright ©2020 Sustainalytic...
# 49  2 Introduction  \nSynthesis Analytics  (the “C...
# 51  Well positioned  to address common environment...
# 53  Disclaimer  \nAll rights reserved. No part of ...
# 55  As part of this engagement, Sustainalytics hel...
# 57  3 Sustainalytics’ Opinion  \nSection 1: Sustai...
#
#                                             Passage 8  \
# 1   6 BPPEH has provided to Sustainalytics a list ...
# 3    \n4. REPORTING  \nOverall comment on section ...
# 5   2 Introduction  \nCibus Nordic Real Estate AB ...
# 7   2 Introduction  \nCTP Group (“CTP”, or “the Co...
# 9   2 Introduction  \nDeutsche Wohnen  SE Group  (...
# 11   \nConclusion   \nGlobalworth has developed th...
# 13  Sustainalytics considers that Icade ’s Green B...
# 15  3 Any update of t he present Second -Party Opi...
# 17  Through consultation, Sustainalytics understan...
# 19  15 Disclaimer  \nCopyright ©202 1 Sustainalyti...
# 21  3 Sustainalytics’ Opinion  \nSection 1: Sustai...
# 23  5 outcomes . Some key environmental and social...
# 25  5  energy,  and promoting biodiversity at its ...
# 27  Additional disclosure:  \n☐ Allocations to fut...
# 29  13 Disclaimer  \n© Sustainalytics 2018. All ri...
# 31   \nConclusion  \nE.ON  SE has developed the E....
# 33  2 Introduction  \nE.ON SE (“E.ON”, the “Issuer...
# 35   \nABOUT ROLE(S) OF INDEPENDENT REVIEW PROVIDE...
# 37  innogy  has engaged S ustainalytics to provide...
# 39  12 © Sustainalytics 2018. All rights reserved....
# 41  Proceeds of the bond s will be used for projec...
# 43  5 •  \n• Technology -enabled operational effic...
# 45   \n3.3 Management of Proce eds  \nProceeds fro...
# 47  5 Section 2: Sustainability Performance of RWE...
# 49  9  \nSection 2 . Review overview  \nSCOPE OF R...
# 51  9 Evaluation and selection  \n☒ Credentials on...
# 53  In addition to the general importance of rail ...
# 55  Given Ferrovie’s use of envi ronmental impact ...
# 57  As part of this engagement, Sustainalytics hel...
#
#                                             Passage 9  \
# 1   Conclusion   \nBPPEH  has developed the Blacks...
# 3   Reporting  \n Yes  Castellum will publish a ye...
# 5   11  \n3. MANAGEMENT  OF PROCEEDS  \nOverall co...
# 7   18 Ministry of Energy, “ Integrated National E...
# 9   3 Sustainalytics’ Second -Party Opinion, while...
# 11  Evaluation Summary  \nSustainalytics is of the...
# 13  6 Similarly to a positive energy building whic...
# 15  6 projects could also lead to negative environ...
# 17  Specialfastigheter has developed a Green Bond ...
# 19  4 been disclosed by the Group  to represent a ...
# 21  13 Disclaimer  \n© Sustainalytics 201 9. All r...
# 23  12 Disc laimer  \nCopyright ©202 1 Sustainalyt...
# 25  4  increase the utilization of renewable energ...
# 27  Xior  has developed the Xior Student Housing N...
# 29  5 Japan has set targets to reduce GHG emission...
# 31  4 methodology, and considers it to directly li...
# 33  6 • Management of Proceeds:  \n-  E.ON  will m...
# 35  ESB h as developed the  ESB Green Bond Framewo...
# 37   \n 13 \n4. REPORTING  \nOverall comment on se...
# 39  Within Midsummer’s  CSR Policy and Code of Con...
# 41  Landsvirkjun has developed a  Green Bond Frame...
# 43  16 Disclaimer  \nCopyright ©202 1 Sustainalyti...
# 45  Sustainalytics considers that the use of proce...
# 47   \nABOUT ROLE(S) OF INDEPENDENT REVIEW PROVIDE...
# 49           4 Capturing the energy of waste -heat.
# 51  13 Disclaimer  \n© Sustainalytics 20 20. All r...
# 53  Reporting  \nAllocation Reporting  \nAlpha Tra...
# 55   \n 11 \nWith regard  to the  traction chain :...
# 57  Evaluation Summary  \nSustainalytics is of the...
#
#                                            Passage 10           labels
# 1   6 implementation of its group -wide  sustainab...    [4, 8, 9, 10]
# 3   Where Castellum is responsible for project ope...           [3, 6]
# 5   14 Disclaimer  \nCopyright ©2020 Sustainalytic...           [3, 8]
# 7   4 environmental impact metrics, see Appendix 2...    [1, 4, 8, 10]
# 9   5 As part of the Company’s  focus on its envir...           [8, 9]
# 11  10 GWI, “Globalworth Real Estate Investments L...     [3, 7, 8, 9]
# 13  However, Sustainalytics notes that t he majori...  [3, 4, 6, 7, 9]
# 15  4 Potential ).6  Furthermore,  in relation to ...     [3, 5, 7, 8]
# 17  Disclaimer  \nAll rights reserved. No part of ...           [3, 9]
# 19  8 Conclusion   \nTritax Euro Box has developed...        [4, 7, 9]
# 21   \nConclusion  \nVesteda’s Green Finance Frame...       [4, 8, 10]
# 23  2 Introduction  \nVía Célere  SL (or the “Comp...          [4, 10]
# 25  6  • As part of its occupational health and sa...        [3, 7, 9]
# 27  4 • Project Evaluation and Selection:  \n- Xio...           [6, 9]
# 29  3 Sustainalytics’ Opinion  \nSection 1: Sustai...          [4, 10]
# 31  Second -Party Opinion  \nE.ON  Green Bond   \n...       [4, 8, 10]
# 33  28 Table 1 3 \nFramework Activity assessed  En...           [4, 8]
# 35  Second -Party Opinion  \nESB G reen Bond   \n ...       [4, 9, 10]
# 37  innogy  has developed a Green Bond F ramework1...    [3, 4, 5, 10]
# 39  3 Sustainalytics’ Opinion  \nSection 1: Sustai...          [4, 10]
# 41  Landsvirkjun  engaged Sustainalytics to provid...     [3, 5, 8, 9]
# 43  2 Introduction  \nNeutral Fuels  LLC  (“Neutra...       [4, 8, 10]
# 45  © Sustainalytics 2016  \n  8 \nSustainalytics’...  [2, 4, 6, 7, 9]
# 47  4 Sustainalytics’ Opinion  \nSection 1: Sustai...          [4, 10]
# 49  5 • The Swedish Work Environment Authority (SW...        [1, 5, 7]
# 51  3 Sustainalytics’ Opinion  \nSection 1: Sustai...          [4, 10]
# 53  Project Evaluation and Selection  Process  \nA...           [4, 6]
# 55  Ferrovie intends to use the proceeds for inves...       [2, 4, 10]
# 57  While electric mobility has a big potential to...        [4, 7, 9]

# %%
df_t5
# Out:
#                                               Company  \
# 0           Blackstone_External%20Review%20Report.pdf
# 2            Castellum_External%20Review%20Report.pdf
# 4                Cibus_External%20Review%20Report.pdf
# 6                  CTP_External%20Review%20Report.pdf
# 8    Deutsche%20Wohnen_External%20Review%20Report.pdf
# 10         Globalworth_External%20Review%20Report.pdf
# 12               ICADE_External%20Review%20Report.pdf
# 14             Johnson_External%20Review%20Report.pdf
# 16  Specialfastigheter-External%20Review%20Report.pdf
# 18      tritax-eurobox_External%20Review%20Report.pdf
# 20             Vesteda_External%20Review%20Report.pdf
# 22  V%C3%ADa%20C%C3%A9lere_External%20Review%20Rep...
# 24             Vonovia_External%20Review%20Report.pdf
# 26                Xior_External%20Review%20Report.pdf
# 28  Baseload%20Capital_External%20Review%20Report.pdf
# 30                E.ON_External%20Review%20Report.pdf
# 32         E.ON_External%20Review%20Report%202021.pdf
# 34                 ESB_External%20Review%20Report.pdf
# 36              innogy_External%20Review%20Report.pdf
# 38           Midsummer_External%20Review%20Report.pdf
# 40        Landsvirkjun-External%20Review%20Report.pdf
# 42     neutral%20fuels_External%20Review%20Report.pdf
# 44             Repower_External%20Review%20Report.pdf
# 46                 RWE_External%20Review%20Report.pdf
# 48  Synthesis%20Analytics_External%20Review%20Repo...
# 50       Water%20Wheel_External%20Review%20Report.pdf
# 52      Alpha%20Trains_External%20Review%20Report.pdf
# 54            Ferrovie_External%20Review%20Report.pdf
# 56   Volkswagen_External%20Review%20Report%202020.pdf
#
#                       Sector                                  Query Method  \
# 0      Corporate-Real Estate  what did the use of proceeds finance?     T5
# 2      Corporate-Real Estate  what did the use of proceeds finance?     T5
# 4      Corporate-Real Estate  what did the use of proceeds finance?     T5
# 6      Corporate-Real Estate  what did the use of proceeds finance?     T5
# 8      Corporate-Real Estate  what did the use of proceeds finance?     T5
# 10     Corporate-Real Estate  what did the use of proceeds finance?     T5
# 12     Corporate-Real Estate  what did the use of proceeds finance?     T5
# 14     Corporate-Real Estate  what did the use of proceeds finance?     T5
# 16     Corporate-Real Estate  what did the use of proceeds finance?     T5
# 18     Corporate-Real Estate  what did the use of proceeds finance?     T5
# 20     Corporate-Real Estate  what did the use of proceeds finance?     T5
# 22     Corporate-Real Estate  what did the use of proceeds finance?     T5
# 24     Corporate-Real Estate  what did the use of proceeds finance?     T5
# 26     Corporate-Real Estate  what did the use of proceeds finance?     T5
# 28          Corporate-Energy  what did the use of proceeds finance?     T5
# 30          Corporate-Energy  what did the use of proceeds finance?     T5
# 32          Corporate-Energy  what did the use of proceeds finance?     T5
# 34          Corporate-Energy  what did the use of proceeds finance?     T5
# 36          Corporate-Energy  what did the use of proceeds finance?     T5
# 38          Corporate-Energy  what did the use of proceeds finance?     T5
# 40          Corporate-Energy  what did the use of proceeds finance?     T5
# 42          Corporate-Energy  what did the use of proceeds finance?     T5
# 44          Corporate-Energy  what did the use of proceeds finance?     T5
# 46          Corporate-Energy  what did the use of proceeds finance?     T5
# 48          Corporate-Energy  what did the use of proceeds finance?     T5
# 50          Corporate-Energy  what did the use of proceeds finance?     T5
# 52  Corporate-Transportation  what did the use of proceeds finance?     T5
# 54  Corporate-Transportation  what did the use of proceeds finance?     T5
# 56  Corporate-Transportation  what did the use of proceeds finance?     T5
#
#                                             Passage 1  \
# 0   12  \nThe eligible categories for the use of p...
# 2   2.3.1  Use of Proceeds  \nThe proceeds of the ...
# 4   6 Conclusion   \nCibus  has developed the Cibu...
# 6   Conclusion  \nCTP  has developed the CTP Green...
# 8   Conclusion   \nDeutsche Wohnen  has developed ...
# 10   \nConclusion   \nGlobalworth has developed th...
# 12    15 \nUse of proceeds categories as per GBP: ...
# 14  Conclusion   \nJCI has developed the Johnson C...
# 16  Specialfastigheter has developed a Green Bond ...
# 18  11 The eligible categories for the use of proc...
# 20  Section 3. Detailed review  \nReviewers are en...
# 22   \nConclusion   \nVía Célere  has developed th...
# 24  Conclusion   \nVonovia  has developed the Vono...
# 26  Conclusion  \nXior  has developed the Xior Stu...
# 28  Section 3. Detailed review  \nReviewers are en...
# 30   \nConclusion  \nE.ON  SE has developed the E....
# 32  37 The eligible categories for the use of proc...
# 34   Use of proceeds:  \n- The four use s of proc...
# 36   \n 11 \nSection 3.  Detailed review  \n1. USE...
# 38  The  Framework is aligned with the four core c...
# 40    18 \nSection 3.  Detailed review  \n1. USE O...
# 42  9 Conclusion  \nNeutral Capital Finance PLC ha...
# 44  1. USE OF PROCEEDS  \nOverall comment on secti...
# 46  Sustainalytics is of the opinion that projects...
# 48  3 In addition, the Second -Party Opinion opine...
# 50  8 Section 3. Detailed review  \nReviewer s are...
# 52  Use of Proceeds  \nEligibility Criteria  \nPro...
# 54  • The eligible categories for the use of proce...
# 56   \nSection 3. Detailed review  \nReviewers are...
#
#                                             Passage 2  \
# 0   Conclusion   \nBPPEH  has developed the Blacks...
# 2   1. USE OF PROCEEDS  \nOverall comment on secti...
# 4   Section 3. Detailed review  \nReviewers are en...
# 6   2 Introduction  \nCTP Group (“CTP”, or “the Co...
# 8   10  \nThe eligible categories for the use of p...
# 10   \nUse of proceeds reporting:  \n☐ Project -by...
# 12  Use of proceeds reporting:  \n☐ Project -by-pr...
# 14  11 The eligible categories for the use of proc...
# 16  As a state -owned entity, Specialfa stigheter ...
# 18  Evaluation Summary  \nSustainalytics is of the...
# 20  Vesteda  has developed the Vesteda Green Finan...
# 22  8 1. USE OF PROCEEDS  \nOverall comment on sec...
# 24  10   \nThe eligible categories for the use of ...
# 26  Xior  has developed the Xior Student Housing N...
# 28   \n4. REPORTING  \nOverall comment on section ...
# 30  The use of proceeds categories specified in th...
# 32  Conclusion  \nE.ON has developed a  Green Bond...
# 34  Section 3. Detailed review  \nReviewer s are e...
# 36   \nSection 3: Impact of Use of Proceeds  \nThe...
# 38  8 Section 3. Detailed review  \nReviewers are ...
# 40  Proceeds of the bond s will be used for projec...
# 42   \nEvaluation Summary  \nSustainalytics is of ...
# 44  3.1 Use of Proceeds  \nRepower  will use the n...
# 46  8  \nSection 3. Detailed review  \nReview ers ...
# 48  6 Renewable Energy  7. Affordable & Clean Ener...
# 50  Water Wheels Green Securities has developed th...
# 52  3. MANAGEMENT OF PROCEEDS  \nOverall comment o...
# 54  The net proceeds of each green bond will be us...
# 56  3 Sustainalytics’ Opinion  \nSection 1: Sustai...
#
#                                             Passage 3  \
# 0   Evaluation Summary  \nSustainalytics is of the...
# 2   Reporting  \n Yes  Castellum will publish a ye...
# 4   3 No information provided by Sustainalytics un...
# 6   9 The eligible categories  for the use of proc...
# 8   Evaluation Summary  \nSustainalytics is of the...
# 10   \nUse of proceeds categories as per GBP:  \n☐...
# 12  Sustainalytics is of the opinion that projects...
# 14  Evaluation Summary  \nSustainalytics is of the...
# 16  12 \n Section 3.  Detailed review  \n1. USE OF...
# 18  8 Conclusion   \nTritax Euro Box has developed...
# 20  3 Sustainalytics’ Opinion  \nSection 1: Sustai...
# 22  2 Introduction  \nVía Célere  SL (or the “Comp...
# 24  2  Introduction  \nVonovia  (“Vonovia ” or the...
# 26  Evaluation Summary  \nSustainalytics is of the...
# 28  3 Sustainalytics’ Opinion  \nSection 1: Sustai...
# 30   \nUse of proceeds categories as per GBP:  \n☒...
# 32   \nUse of proceeds reporting:  \n☐ Project -by...
# 34  8 ESB has developed the ESB Green Bond Framewo...
# 36  The importance of clean t ransportation projec...
# 38  Midsummer h as developed the  Midsummer Green ...
# 40  Landsvirkjun has developed a  Green Bond Frame...
# 42  12 The eligible categories  for the use of pro...
# 44  Given this context, Sustainalytics considers t...
# 46  4 Sustainalytics’ Opinion  \nSection 1: Sustai...
# 48  2 Introduction  \nSynthesis Analytics  (the “C...
# 50  Evaluation Summary  \nSustainalytics is of the...
# 52   \nUse of proceeds categories as per GBP:  \n☐...
# 54  Ferrovie intends to use the proceeds for inves...
# 56   \nConclusion  \nVW has developed the Volkswag...
#
#                                             Passage 4  \
# 0   5 • Project Evaluation and Selection:  \n- BPP...
# 2    \n 5 applicable criteria or to repay a Green ...
# 4   Use of proceeds categories as per GBP:  \n☐ Re...
# 6   Use of proceeds categories as per GBP:  \n☒ Re...
# 8    \nUse of proceeds categories as per GBP:  \n☒...
# 10  The eligible categor ies  for the use of proce...
# 12    3 \nIcade has engaged Sustainalytics to prov...
# 14  Use of proceeds categories as per GBP:  \n☒ Re...
# 16  Use of proceeds categories as per GBP:  \n☒ Re...
# 18  3 Sustainalytics ' Second -Party Opinion, whil...
# 20  Use of proceeds categories as per GBP:  \n☐ Re...
# 22  Evaluation Summary  \nSustainalytics is of the...
# 24  Evaluation Summary  \nSustainalytics is of the...
# 26  Section 3. Detailed review  \nReviewers are en...
# 28  Use of proceeds categories as per GBP:  \n☒ Re...
# 30  E.ON  has developed the E.ON Green Bond Framew...
# 32   \nUse of proceeds categories as per GBP:  \n☒...
# 34  ESB h as developed the  ESB Green Bond Framewo...
# 36   \nConclusion  \ninnogy , a European energy co...
# 38  Use of Proceeds \nCategory  SDG  SDG target  \...
# 40   \nUse of proceeds categories as per GBP:  \n☒...
# 42  3 measurement and reporting of the impact achi...
# 44  Sustainalytics considers that the use of proce...
# 46  2 Introduction  \nIn 2020, RWE  (“RWE ”, or th...
# 48  Use of proceeds categories as per GBP:  \n☒ Re...
# 50   \nUse of proceeds reporting:  \n☒ Project -by...
# 52  Use of proceeds reporting:  \n☒ Project -by-pr...
# 54  Use of proceeds categories as per GBP:  \n☐ Re...
# 56  VW has developed the Volkswagen Green Finance ...
#
#                                             Passage 5  \
# 0   The Company, under the supervision of the Gree...
# 2   Although Castellum does not commit to a ratio ...
# 4   2 Introduction  \nCibus Nordic Real Estate AB ...
# 6   Evaluation Summary  \nSustainalytics is of the...
# 8   3 Sustainalytics’ Second -Party Opinion, while...
# 10  2 Introduction  \nGlobalworth Real Estate Inve...
# 12   \nConclusion  \nIcade, one of the leading com...
# 14  3 Any update of t he present Second -Party Opi...
# 16  Use of proceeds reporting:  \n☒ Project -by-pr...
# 18  13 Use of proceeds reporting : \n☐ Project -by...
# 20  Use of proceeds reporting:  \n☐ Project -by-pr...
# 22  Use of proceeds categories as per GBP:  \n☐ Re...
# 24   \nUse of proceeds categories as per GBP:  \n☒...
# 26  3 Sustainalytics’ Opinion  \nSection 1: Sustai...
# 28  Baseload Capital has developed the Baseload Ca...
# 30  Use of proceeds reporting:  \n☐ Project -by-pr...
# 32  Alignment with the Green Bond Principles 2018 ...
# 34  Based on ESB’  policies , programmes  and proc...
# 36  Furthermore , the European Commission consider...
# 38   \nUse of proceeds categories as per  GBP:  \n...
# 40  Use of proceeds reporting:  \n☐ Project -by-pr...
# 42   \nUse of proceeds categories as per GBP:  \n☐...
# 44   \nUse of proceeds categories as per GBP:  \n☒...
# 46  Evaluation Summary  \nSustainalytics is of the...
# 48  ROLE(S) OF REVIEW PROVIDER  \n☒ Consultancy (i...
# 50  Use of proceeds categories as per GBP:  \n☒ Re...
# 52   12 \nSection 3.  Detailed review  \nReviewers...
# 54  Having reviewed Ferrovie ’s Green Bond Framewo...
# 56  Section 3: Impact of Use of Proceeds  \nThe us...
#
#                                             Passage 6  \
# 0   Use of proceeds reporting : \n☐ Project -by-pr...
# 2   2.3.2  Process for Project Evaluation and Sele...
# 4   Evaluation Summary  \nSustainalytics is of the...
# 6   4. REPORTING  \nOverall comment on section (if...
# 8   2 Introduction  \nDeutsche Wohnen  SE Group  (...
# 10  4 Sustainalytics’ Opinion  \nSection 1: Sustai...
# 12  However, Sustainalytics notes that t he majori...
# 14  According to the International Energy Agency (...
# 16  Overall, Sustainalytics is of the opinion that...
# 18  Use of proceeds categories as per GBP:  \n☒ Re...
# 20  As part of this engagement, Sustainalytics hel...
# 22  4. REPORTING  \nOverall comment on section (if...
# 24  12  Use of proceeds reporting : \n☐ Project -b...
# 26  Use of proceeds reporting:  \n☐ Project -by-pr...
# 28  Section 3: Impact of Use of Proceeds  \nBoth u...
# 30  Section 3: Impact of Use of Proceeds  \nAll th...
# 32  Sustaina lytics has assessed  E.ON ’s Green Bo...
# 34  Well positioned to address common environmenta...
# 36   \n 6 \nContributing to a sustainable energy t...
# 38  Use of proceeds reporting:  \n☐ Project -by-pr...
# 40  Contributing to  Iceland’s  100% renewable ene...
# 42  4. REPORTING  \nOverall comment on section (if...
# 44  © Sustainalytics 2016  \n  9 \nImpact of use o...
# 46  10 Use of proceeds reporting:  \n☐ Project -by...
# 48  Use of proceeds reporting:  \n☐ Project -by-pr...
# 50  Well positioned  to address common environment...
# 52  Section 2.  Review overview  \nSCOPE OF REVIEW...
# 54  While the energy efficiency improvements  decl...
# 56  Use of proceeds categories as per GBP:  \n☐ Re...
#
#                                             Passage 7  \
# 0    \nUse of proceeds categories as per GBP:  \n☒...
# 2   2.3 Castellum’s Green Bond  \nCastellum intend...
# 4   13 overarching objectives, strategy, policy an...
# 6   3 No infor mation provided by Sustainalytics u...
# 8   Net proceeds will be managed by Deutsche Wohne...
# 10  10  \nSection 3. Detailed review  \nReviewers ...
# 12  • Strong commitment to allocation and imp act ...
# 14  2 Introduction  \nJohnson Controls Internation...
# 16  3. MANAGEMENT OF PROCEEDS  \nOverall comment o...
# 18  4. REPORTING  \nOverall comment on section (if...
# 20  Second -Party Opinion  \nVesteda  Green Financ...
# 22  9 Information on Responsibilities  and Account...
# 24  3  In additio n, the Second -Party Opinion opi...
# 26  Well positioned to address common environmenta...
# 28  As part of this engagement, Sustainalytics hel...
# 30  As part of this engagement, Sustainalytics hel...
# 32  Section 3. Detailed review  \nReviewe rs are e...
# 34  Use of proceeds categories as per GBP:  \n☒ Re...
# 36  Section 1: Sustainalytics’ Opinion on the inno...
# 38  3 Sustainalytics’ Opinion  \nSection 1: Sustai...
# 40  Landsvirkjun, Iceland’s largest electricity co...
# 42  2 Introduction  \nNeutral Fuels  LLC  (“Neutra...
# 44  © Sustainalytics 2016  \n  8 \nSustainalytics’...
# 46  Use of proceeds categories as per GBP:  \n☒ Re...
# 48  Evaluation Summary  \nSustainalytics is of the...
# 50  3 Sustainalytics’ Opinion  \nSection 1: Sustai...
# 52  Project Evaluation and Selection  Process  \nA...
# 54  As part of this engagement, Sustainalytics hel...
# 56  Use of proceeds reporting:  \n☐ Project -by-pr...
#
#                                             Passage 8  \
# 0   BPPEH  engaged Sustainalytics to review the  F...
# 2   Castellum will publish a yearly report describ...
# 4   4. REPORTING  \nOverall comment on section (if...
# 6   Section 3. Detailed review  \nReviewe rs are e...
# 8   Deutsche Wohnen  intends to report on the allo...
# 10  Evaluation Summary  \nSustainalytics is of the...
# 12    16 \n3. MANAGEMENT OF PROCEEDS  \nOverall co...
# 14  Section 3. Detailed review  \nReviewe rs are e...
# 16  Specialfastigheter  has engaged Sustainalytics...
# 18  Section 3. Detailed review  \nReviewers are en...
# 20  Contribution of framework to Vesteda’s  sustai...
# 22  3 No information provided by Sustainalytics un...
# 24  Section 3. Detailed review  \nReviewe rs are e...
# 26  The Xior Student Housing N.V. Green Finance Fr...
# 28  12 sustainable features of underlying assets m...
# 30  Imp ortance of clean transportation in mitigat...
# 32  10 procurement of goods and services.32 E.ON’s...
# 34  ESB’s process for project evaluation and selec...
# 36   \nUse of proceeds categories as per GBP:  \n☒...
# 38  As part of this engagement, Sustainalytics hel...
# 40  3. MANAGEMENT OF PROCEEDS  \nOverall comment o...
# 42  Section 3. Detailed review  \nReviewe rs are e...
# 44  Repower will use the net proceeds of the Green...
# 46   \nABOUT ROLE(S) OF INDEPENDENT REVIEW PROVIDE...
# 48  9  \nSection 2 . Review overview  \nSCOPE OF R...
# 50   \nABOUT ROLE(S) OF INDEPENDENT REVIEW PROVIDE...
# 52  Disclaimer  \nAll rights reserved. No part of ...
# 54   \n 15 \nRegarding impact reporting, Ferrovie ...
# 56  Evaluation Summary  \nSustainalytics is of the...
#
#                                             Passage 9  \
# 0   7 Section 3: Impact of Use of Proceeds  \nAll ...
# 2   2.2.3  Management of Proceeds   \nGreen Bond n...
# 4   5 Section 3: Impact of Use of Proceeds  \nThe ...
# 6   12 SPECIFY OTHER EXTERNAL REVIEWS AVAILABLE, I...
# 8   Section 3. Detailed review  \nReviewers are en...
# 10  ABOUT ROLE(S) OF INDEPENDENT REVIEW PROVIDERS ...
# 12  Contribu tion of the proceeds of the green bon...
# 14  4. REPORTING  \nOverall comment on section (if...
# 16  Disclaimer  \nAll rights reserved. No part of ...
# 18  2 Introduction  \nTritax EuroBox plc  ("Tritax...
# 20  3. MANAGEMENT OF PROCEEDS  \nOverall comment o...
# 22  11 SPECIFY OTHER EXTERNAL REVIEWS AVAILABLE, I...
# 24  4  increase the utilization of renewable energ...
# 26  Use of proceeds categories as per GBP:  \n☒ Re...
# 28  Second -Party Opinion  \nBaseload Capital  Gre...
# 30  Section 3. Detailed review  \nReviewers are en...
# 32   \n13 \n Appendi ces  \nAppendix 1: Approach t...
# 34  As part of this engagement, Sustainalytics hel...
# 36  2. PROCESS FOR PROJECT EVALUATION AND SELECTIO...
# 38  Review provider(s):  Date of publication:  \n ...
# 40  Landsvirkjun  engaged Sustainalytics to provid...
# 42  8 Alignment with/contribution to SDGs  \nThe S...
# 44  © Sustainalytics 2016  \n  2 \nTABLE OF CONTEN...
# 46  Section 2 . Review overview  \nSCOPE OF REVIEW...
# 48   \nABOUT ROLE(S) OF INDEPENDENT REVIEW PROVIDE...
# 50  As part of this engagement, Sustainalytics hel...
# 52  Conclusion   \nClean transportation is recogni...
# 54  Alignment with/contribution to SDGs  \nThe Sus...
# 56  VW  intends to use its Green Bo nds’ and Loans...
#
#                                            Passage 10  \
# 0   3 This docum ent contains Sustainalytics’ opin...
# 2    \n4. REPORTING  \nOverall comment on section ...
# 4   9 Review provider’s name:  Sustainalytics  \nC...
# 6   5 habitats.” Concerning land use the Directive...
# 8   4 - Within the Renewable Energy category, Deut...
# 10  Section 2 . Review overview  \nSCOPE OF REVIEW...
# 12  Tracking of proceeds:  \n☒ Green  Bond proceed...
# 14  14 Review provider(s):  Date of publication:  ...
# 16  Through consultation, Sustainalytics understan...
# 18  SPECIFY OTHER EXTERNAL REVIEWS AVAILABLE, IF A...
# 20  4 • Reporting:  \n- Vesteda will report on the...
# 22  7 Append ix \nAppend ix 1: Green B ond / Green...
# 24  6  • As part of its occupational health and sa...
# 26  Based on these policies, standards and assessm...
# 28   \nABOUT ROLE(S) OF INDEPENDENT REVIEW PROVIDE...
# 30  Second -Party Opinion  \nE.ON  Green Bond   \n...
# 32  2 Introduction  \nE.ON SE (“E.ON”, the “Issuer...
# 34   \n4. REPORTING  \nOverall comment on section ...
# 36  Use of proceeds reporting:  \n☒ Project -by-pr...
# 38  Section 2 . Review overview  \nSCOPE OF REVIEW...
# 40  Overall, Sustainalytics is confident that the ...
# 42  15 ☐ Verification / Audit  ☐ Rating  \n☐ Other...
# 44  For this issuance, Repower will use the net pr...
# 46  9 ☒ Defined and transparent criteria for proje...
# 48  5 • The Swedish Work Environment Authority (SW...
# 50   \nConclusion  \nWater Wheel Green Securities ...
# 52  In addition to compliance with ESG Policy, Alp...
# 54  The company’s management of the bond proceeds ...
# 56  As part of this engagement, Sustainalytics hel...
#
#                       labels
# 0        [1, 2, 3, 7, 9, 10]
# 2               [2, 5, 6, 7]
# 4         [1, 2, 3, 5, 6, 9]
# 6     [1, 2, 3, 4, 5, 7, 10]
# 8     [1, 2, 3, 4, 5, 6, 10]
# 10        [1, 3, 4, 5, 6, 8]
# 12                    [1, 5]
# 14     [1, 2, 3, 4, 5, 6, 7]
# 16           [1, 2, 3, 4, 6]
# 18        [1, 2, 3, 4, 6, 9]
# 20           [1, 2, 3, 4, 7]
# 22           [1, 2, 3, 5, 8]
# 24           [1, 2, 3, 5, 9]
# 26        [1, 2, 3, 4, 5, 9]
# 28           [1, 3, 4, 5, 9]
# 30             [1, 3, 4, 10]
# 32          [1, 2, 4, 5, 10]
# 34           [1, 2, 3, 4, 7]
# 36  [1, 2, 3, 4, 5, 6, 7, 8]
# 38        [1, 2, 3, 4, 5, 7]
# 40           [1, 2, 3, 4, 7]
# 42        [1, 2, 3, 4, 5, 7]
# 44    [1, 2, 3, 4, 5, 8, 10]
# 46           [2, 3, 4, 5, 7]
# 48           [1, 2, 3, 4, 7]
# 50       [1, 2, 3, 5, 7, 10]
# 52                 [1, 2, 3]
# 54              [1, 2, 3, 4]
# 56        [1, 2, 3, 4, 8, 9]

# %%
def calculate_metrics(df):
  labels = df["labels"]

  # recall@1
  recall_1 = len([label for label in labels if 1 in label]) / len(labels)
  # recall@5
  recall_5 = len([label for label in labels if any(item in label for item in list(range(1,6)))]) / len(labels)

  # mrr@5
  mrr_5 = [1/label[0] if label[0] <= 5 else 0 for label in df["labels"]]
  mrr_5 = sum(mrr_5) / len(mrr_5)

  # mrr@10
  mrr_10 = [1/label[0] if label[0] <= 10 else 0 for label in df["labels"]]
  mrr_10 = sum(mrr_10) / len(mrr_10)

  # map@5
  map_5 = []
  # map@10
  map_10 = []
  # for each label:
  # e.g. [4, 8, 9, 10]
  for label in df["labels"]:
    # @ 5 - [4]
    five = [num for num in label if num <= 5]
    # @ 10 - [4, 8, 9, 10]
    ten = [num for num in label if num <= 10]

    if five:
      # get average precision
      mini_5 = []
      for i, item in enumerate(five):
        # i+1 tracks the index of how many correct answers - e.g. 0+1 (for first answer)
        # item tracks the rank of correct answer - e.g. following example : 4
        mini_5.append( ((i+1)/item) )
      # average precision : (1/4) / 1
      avg_precision = sum(mini_5) / len(mini_5)
      # Store in main list
      map_5.append(avg_precision)
    else:
      map_5.append(0)

    if ten:
      # get average precision
      mini_10 = []
      for i, item in enumerate(ten):
        mini_10.append( ((i+1)/item) )
      # avg precision : (1/4 + 2/8 + 3/9 + 4/10) / 4
      avg_precision = sum(mini_10) / len(mini_10)
      # Store in main list
      map_10.append(avg_precision)
    else:
      map_10.append(0)

  map_5 = sum(map_5) / len(map_5)
  map_10 = sum(map_10) / len(map_10)

  return {
      "recall@1" : recall_1,
      "recall@5" : recall_5,
      "MRR@5" : mrr_5,
      "MRR@10" : mrr_10,
      "MAP@5" : map_5,
      "MAP@10" : map_10
  }

# %%
calculate_metrics(df_t5)
# Out:
# {'recall@1': 0.9310344827586207,
#  'recall@5': 1.0,
#  'MRR@5': 0.9655172413793104,
#  'MRR@10': 0.9655172413793104,
#  'MAP@5': 0.9286398467432949,
#  'MAP@10': 0.878488023561915}

# %%
calculate_metrics(df_bert)
# Out:
# {'recall@1': 0.10344827586206896,
#  'recall@5': 0.9310344827586207,
#  'MRR@5': 0.35344827586206895,
#  'MRR@10': 0.36350574712643674,
#  'MAP@5': 0.34463601532567045,
#  'MAP@10': 0.3622883732036875}
